# %% [markdown]
# ## Customize Your Lineup - Trial Code
# Get the python/pandas logic working for the customize page before incorporating it into the flask app/js/html.

# %%
import pandas as pd
import numpy as np
from scipy import stats

# #try using plotly for graphing - should help transition to later javascript graphs
# import plotly
# import plotly.plotly as py
# import plotly.figure_factory as ff
# import plotly.graph_objs as go
# #need to use Plotly API Key in order to get it to run
# plotly.tools.set_credentials_file(username='mtsuomi', api_key='KU6JDtNccJICaVmeF2gF')

from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
from sqlalchemy.ext.automap import automap_base
import json

# %%
#create engine to the database
db = create_engine('sqlite:///../fantasy_football_2018.db')

#create inspector so can see schema of database visually
inspector = inspect(db)

#Database Schema - verify the database has the info we are expecting by printing out all the schema visually
for table_name in inspector.get_table_names():
    for column in inspector.get_columns(table_name):
        print(table_name, column.get('name'), column.get('type'))
    print()

#other options for using SQLAlchemy sort of coding instead of traditional SQL queries
# engine = create_engine('sqlite:///raw_data/hawaii.sqlite')
# Base = automap_base()
# Base.prepare(engine, reflect=True)
# session = Session(bind=engine)
# inspector = inspect(engine)
# Out:
# def_scores Unnamed: 0 BIGINT
# def_scores PLAYER, TEAM POS TEXT
# def_scores team_abbr TEXT
# def_scores week_2_opp TEXT
# def_scores week_2_proj FLOAT
# def_scores week_2_actual BIGINT
# def_scores week_3_opp TEXT
# def_scores week_3_proj FLOAT
# def_scores binned TEXT
# def_scores score_sentiment TEXT
#
# week1_ppr_actuals PLAYER TEXT
# week1_ppr_actuals POS TEXT
# week1_ppr_actuals TEAM TEXT
# week1_ppr_actuals FPTS_PPR_ACTUAL FLOAT
# week1_ppr_actuals WEEK BIGINT
# week1_ppr_actuals PK INTEGER
#
# week1_ppr_projections PLAYER TEXT
# week1_ppr_projections POS TEXT
# week1_ppr_projections TEAM TEXT
# week1_ppr_projections FPTS_PPR_ESPN FLOAT
# week1_ppr_projections FPTS_PPR_CBS FLOAT
# week1_ppr_projections FPTS_PPR_SHARKS FLOAT
# week1_ppr_projections FPTS_PPR_SCOUT FLOAT
# week1_ppr_projections FPTS_PPR_PRVS_WK_ACTUAL FLOAT
# week1_ppr_projections PK INTEGER
#
# week1_ppr_projections_all_scraped PLAYER TEXT
# week1_ppr_projections_all_scraped POS TEXT
# week1_ppr_projections_all_scraped TEAM TEXT
# week1_ppr_projections_all_scraped FPTS_PPR_ESPN FLOAT
# week1_ppr_projections_all_scraped FPTS_PPR_CBS FLOAT
# week1_ppr_projections_all_scraped FPTS_PPR_SHARKS FLOAT
# week1_ppr_projections_all_scraped FPTS_PPR_SCOUT FLOAT
# week1_ppr_projections_all_scraped FPTS_PPR_PRVS_WK_ACTUAL FLOAT
# week1_ppr_projections_all_scraped PK INTEGER
#
# week1_salaries_fanduel PLAYER TEXT
# week1_salaries_fanduel POS TEXT
# week1_salaries_fanduel TEAM TEXT
# week1_salaries_fanduel SALARY_FANDUEL TEXT
# week1_salaries_fanduel WEEK TEXT
# week1_salaries_fanduel PK INTEGER
#
# week2_ppr_actuals PLAYER TEXT
# week2_ppr_actuals POS TEXT
# week2_ppr_actuals TEAM TEXT
# week2_ppr_actuals FPTS_PPR_ACTUAL FLOAT
# week2_ppr_actuals WEEK BIGINT
# week2_ppr_actuals PK INTEGER
#
# week2_ppr_projections PLAYER TEXT
# week2_ppr_projections POS TEXT
# week2_ppr_projections TEAM TEXT
# week2_ppr_projections FPTS_PPR_ESPN FLOAT
# week2_ppr_projections FPTS_PPR_CBS FLOAT
# week2_ppr_projections FPTS_PPR_SHARKS FLOAT
# week2_ppr_projections FPTS_PPR_SCOUT FLOAT
# week2_ppr_projections FPTS_PPR_PRVS_WK_ACTUAL FLOAT
# week2_ppr_projections PK INTEGER
#
# week2_ppr_projections_all_scraped PLAYER TEXT
# week2_ppr_projections_all_scraped POS TEXT
# week2_ppr_projections_all_scraped TEAM TEXT
# week2_ppr_projections_all_scraped FPTS_PPR_ESPN FLOAT
# week2_ppr_projections_all_scraped FPTS_PPR_CBS FLOAT
# week2_ppr_projections_all_scraped FPTS_PPR_SHARKS FLOAT
# week2_ppr_projections_all_scraped FPTS_PPR_SCOUT FLOAT
# week2_ppr_projections_all_scraped FPTS_PPR_PRVS_WK_ACTUAL FLOAT
# week2_ppr_projections_all_scraped PK INTEGER
#
# week2_salaries_fanduel PLAYER TEXT
# week2_salaries_fanduel POS TEXT
# week2_salaries_fanduel TEAM TEXT
# week2_salaries_fanduel SALARY_FANDUEL BIGINT
# week2_salaries_fanduel WEEK BIGINT
# week2_salaries_fanduel PK INTEGER
#
# week3_ppr_projections PLAYER TEXT
# week3_ppr_projections POS TEXT
# week3_ppr_projections TEAM TEXT
# week3_ppr_projections FPTS_PPR_ESPN FLOAT
# week3_ppr_projections FPTS_PPR_CBS FLOAT
# week3_ppr_projections FPTS_PPR_SHARKS FLOAT
# week3_ppr_projections FPTS_PPR_SCOUT FLOAT
# week3_ppr_projections FPTS_PPR_PRVS_WK_ACTUAL FLOAT
# week3_ppr_projections PK INTEGER
#
# week3_ppr_projections_all_scraped PLAYER TEXT
# week3_ppr_projections_all_scraped POS TEXT
# week3_ppr_projections_all_scraped TEAM TEXT
# week3_ppr_projections_all_scraped FPTS_PPR_ESPN FLOAT
# week3_ppr_projections_all_scraped FPTS_PPR_CBS FLOAT
# week3_ppr_projections_all_scraped FPTS_PPR_SHARKS FLOAT
# week3_ppr_projections_all_scraped FPTS_PPR_SCOUT FLOAT
# week3_ppr_projections_all_scraped FPTS_PPR_PRVS_WK_ACTUAL FLOAT
# week3_ppr_projections_all_scraped PK INTEGER
#
# week3_salaries_fanduel PLAYER TEXT
# week3_salaries_fanduel POS TEXT
# week3_salaries_fanduel TEAM TEXT
# week3_salaries_fanduel SALARY_FANDUEL BIGINT
# week3_salaries_fanduel WEEK BIGINT
# week3_salaries_fanduel PK INTEGER
#
# week_3_over_unders Unnamed: 0 BIGINT
# week_3_over_unders team TEXT
# week_3_over_unders over_under FLOAT
# week_3_over_unders team_abbr TEXT
# week_3_over_unders binned TEXT
# week_3_over_unders score_sentiment TEXT
#
# week_3_tweets Unnamed: 0 BIGINT
# week_3_tweets number BIGINT
# week_3_tweets player TEXT
# week_3_tweets compound_score FLOAT
# week_3_tweets binned TEXT
# week_3_tweets expert_sentiment TEXT
# week_3_tweets color TEXT
# week_3_tweets all_tweets TEXT

# %% [markdown]
# ##### Customize Projection Average

# %%
week = 3
espn_wt = 15
cbs_wt = 40
sharks_wt = 15
scout_wt = 0
prior_wt = 30
def_boost_wt = 'Full'
overunder_boost_wt = 'Partial'
twitter_boost_wt = 'None'

#convert weights to percentages
espn_pct = espn_wt/100
cbs_pct = cbs_wt/100
sharks_pct = sharks_wt/100
scout_pct = scout_wt/100
prior_pct = prior_wt/100

# %%
#get the projections for your week selected
stmt = f"""
        SELECT *
        FROM week{week}_ppr_projections
       """

#need to input db.session.bind in flask app due to different initalization process
df_proj = pd.read_sql_query(stmt, db)
print(df_proj.shape)
df_proj.head()
# Out:
# (357, 9)
#             PLAYER POS TEAM  FPTS_PPR_ESPN  FPTS_PPR_CBS  FPTS_PPR_SHARKS  \
# 0     Alvin Kamara  RB   NO           21.8          21.0             20.8
# 1  Ezekiel Elliott  RB  Dal           21.1          15.0             20.6
# 2        Tom Brady  QB   NE           20.9          23.0             23.6
# 3      Todd Gurley  RB  LAR           20.9          23.0             20.9
# 4    Antonio Brown  WR  Pit           20.2          23.0             22.9
#
#    FPTS_PPR_SCOUT  FPTS_PPR_PRVS_WK_ACTUAL  PK
# 0            30.4                     17.9   1
# 1            20.7                     19.7   2
# 2            26.4                     16.4   3
# 3            30.5                     32.3   4
# 4            25.1                     15.7   5

# %%
df_proj.columns
# Out:
# Index(['PLAYER', 'POS', 'TEAM', 'FPTS_PPR_ESPN', 'FPTS_PPR_CBS',
#        'FPTS_PPR_SHARKS', 'FPTS_PPR_SCOUT', 'FPTS_PPR_PRVS_WK_ACTUAL', 'PK'],
#       dtype='object')

# %%
#create initial custom weighted average of the five projection sources based on user input
df_proj['FPTS_PPR_CUSTOM_AVG'] = df_proj.apply(lambda row: 
                                    (row['FPTS_PPR_ESPN']*espn_pct +
                                    row['FPTS_PPR_CBS']*cbs_pct +
                                    row['FPTS_PPR_SHARKS']*sharks_pct +
                                    row['FPTS_PPR_SCOUT']*scout_pct +
                                    row['FPTS_PPR_PRVS_WK_ACTUAL']*prior_pct),
                                    axis='columns')
df_proj.head()
# Out:
#             PLAYER POS TEAM  FPTS_PPR_ESPN  FPTS_PPR_CBS  FPTS_PPR_SHARKS  \
# 0     Alvin Kamara  RB   NO           21.8          21.0             20.8
# 1  Ezekiel Elliott  RB  Dal           21.1          15.0             20.6
# 2        Tom Brady  QB   NE           20.9          23.0             23.6
# 3      Todd Gurley  RB  LAR           20.9          23.0             20.9
# 4    Antonio Brown  WR  Pit           20.2          23.0             22.9
#
#    FPTS_PPR_SCOUT  FPTS_PPR_PRVS_WK_ACTUAL  PK  FPTS_PPR_CUSTOM_AVG
# 0            30.4                     17.9   1               20.160
# 1            20.7                     19.7   2               18.165
# 2            26.4                     16.4   3               20.795
# 3            30.5                     32.3   4               25.160
# 4            25.1                     15.7   5               20.375

# %% [markdown]
# ##### Boost Factor Logic - Import Data (later DB connection), Merge Data, then Do Logic

# %%
# ### FIGURE OUT UPDATED DB CONNECTION LATER ###
# #import the data for now
# df_opp_defense = pd.read_excel('../def_scoring_proj.xlsx')
# df_overunder = pd.read_csv('../week_2_over_unders.csv')
# df_tweets = pd.read_csv('../expert_tweets_week_3.csv')

# %%
#get the defense data for your week selected - all defense data for each week is one database,
#select only columns you want
#NOTE - currently it is pulling in defense sentiment always for week 3 - no sentiments for other weeks
stmt_def = f"""
        SELECT team_abbr, week_{week}_opp, week_{week}_proj, score_sentiment
        FROM def_scores
       """

#need to input db.session.bind in flask app due to different initalization process
df_defense = pd.read_sql_query(stmt_def, db)

#currently score_sentiment is for the offensive opponenet perspective so Min's really good Defense
#against Buf has score sentiment of 'Terrible' which is terrible for Buf, so all Buf players
#would get negative points weighting - rename column
#rename team_abbr to def_team_abbr
df_defense.rename(columns={'score_sentiment': 'offense_opp_def_impact',
                           'team_abbr': 'def_team_abbr'}, inplace=True)

print(df_defense.shape)
df_defense.head()
# Out:
# (32, 4)
#   def_team_abbr week_3_opp  week_3_proj offense_opp_def_impact
# 0           NYJ        Cle          5.2                Neutral
# 1           Min        Buf         13.2               Terrible
# 2           Bal        Den          6.7                Neutral
# 3           LAR        LAC          6.8                Neutral
# 4           Chi        Ari          6.5                Neutral

# %%
#get the overunder data for your week selected
#select only columns you want
stmt_overunder = f"""
        SELECT *
        FROM week_{week}_over_unders
       """

#need to input db.session.bind in flask app due to different initalization process
df_overunder = pd.read_sql_query(stmt_overunder, db)
print(df_overunder.shape)
df_overunder.head()
# Out:
# (32, 6)
#    Unnamed: 0               team  over_under team_abbr            binned  \
# 0           0  Arizona Cardinals        37.5       Ari    (37.0, 40.146]
# 1           1    Atlanta Falcons        53.5       Atl    (52.479, 56.5]
# 2           2   Baltimore Ravens        43.5       Bal  (42.792, 48.958]
# 3           3      Buffalo Bills        41.0       Buf  (40.146, 42.792]
# 4           4  Carolina Panthers        43.5       Car  (42.792, 48.958]
#
#   score_sentiment
# 0        Terrible
# 1         Awesome
# 2         Neutral
# 3       Concerned
# 4         Neutral

# %%
#get the tweet data for your week selected
#select only columns you want
stmt_tweets = f"""
        SELECT *
        FROM week_{week}_tweets
       """

#need to input db.session.bind in flask app due to different initalization process
df_tweets = pd.read_sql_query(stmt_tweets, db)
print(df_tweets.shape)
df_tweets.head()
# Out:
# (200, 8)
#    Unnamed: 0  number              player  compound_score         binned  \
# 0           0       1          Cam Newton       -0.223550  (-0.5, -0.02]
# 1           1       2          Drew Brees        0.168067    (0.02, 0.5]
# 2           2       3       Aaron Rodgers        0.062883    (0.02, 0.5]
# 3           3       4          Alex Smith        0.085200    (0.02, 0.5]
# 4           4       5  Ben Roethlisberger        0.041513    (0.02, 0.5]
#
#   expert_sentiment   color                                         all_tweets
# 0        Concerned  yellow  ['Matt Ryan did his best Cam Newton impression...
# 1             Good    blue  ['Drew Brees leads comeback win over Browns ht...
# 2             Good    blue  ['Aaron Rodgers escapes without further damage...
# 3             Good    blue  ['RT @JeffRatcliffe: QBs without any end zone ...
# 4             Good    blue  ['Ben Roethlisberger back at practice Friday h...

# %%
# #Connor's code for binning the over-unders
# high = df_overunder['over_under'].max()
# print(high)
# low = df_overunder['over_under'].min()
# print(low)
# mean = df_overunder['over_under'].mean()
# print(mean)

# #create bins from range of over unders
# bins = [(low-.5), ((low+low+mean)/3), ((low+mean+mean)/3), ((high+mean+mean)/3), ((high+high+mean)/3), (high+.5)]
# df_overunder['binned'] = pd.cut(df_overunder['over_under'], bins)
# df_overunder.head()

# #convert binned values to string so we can categorize with adjectives
# df_overunder['binned'] = df_overunder['binned'].map(lambda x: str(x))

# #create adjectives from bins
# score_bins = {
#     '(42.0, 43.521]': 'Terrible',
#     '(43.521, 44.542]': 'Concerned',
#     '(44.542, 48.208]': 'Neutral',
#     '(48.208, 50.854]': 'Good',
#     '(50.854, 54.0]': 'Awesome'
# }

# df_overunder['score_sentiment'] = df_overunder['binned'].map(score_bins)

# color_bins = {
#     'Terrible': 'red',
#     'Concerned': 'yellow',
#     'Neutral': 'grey',
#     'Good': 'blue',
#     'Awesome': 'green'
# }

# df_overunder['color'] = df_overunder['score_sentiment'].map(color_bins)
# df_overunder

# %%
#merge on the boost factor data to players
#data: opposing defense, opposing defense bin, twitter sentiment, twitter sentiment bin, vegas overunder, vegas overunder bin

#check size of starting df
print(df_proj.shape)

#first merge in the twitter sentiment - always do left merge (rather have Nans for boost factors than lose players)
df_boosts = pd.merge(df_proj, df_tweets[['player', 'compound_score', 'expert_sentiment']],
                     how='left', left_on='PLAYER', right_on='player')
df_boosts.drop('player', axis='columns', inplace=True) #don't need to keep this added player name column
print(df_boosts.shape)

#second merge in the overunder - always do left merge (rather have Nans for boost factors than lose players)
df_boosts = pd.merge(df_boosts, df_overunder[['team_abbr', 'over_under', 'score_sentiment']],
                     how='left', left_on='TEAM', right_on='team_abbr')
df_boosts.drop('team_abbr', axis='columns', inplace=True) #don't need to keep this added team abbr column
print(df_boosts.shape)

#third merge in the defense projections - always do left merge (rather have Nans for boost factors than lose players)
#will merge by the team of the datframe and in defense looking for the opponent (that is offensive opponent of the defense listed as team)
df_boosts = pd.merge(df_boosts, df_defense[['def_team_abbr', f"week_{week}_opp", f"week_{week}_proj", 'offense_opp_def_impact']],
                     how='left', left_on='TEAM', right_on=f"week_{week}_opp")
df_boosts.drop(f"week_{week}_opp", axis='columns', inplace=True) #don't need to keep this added team abbr column
print(df_boosts.shape)

#convert any of the Nans in our binned sentiment columns to Neutral (that will just apply a zero boost to those players)
df_boosts.fillna('Neutral', inplace=True)

df_boosts.head(30)
# Out:
# (357, 10)
# (357, 12)
# (357, 14)
# (357, 17)
#                  PLAYER POS TEAM  FPTS_PPR_ESPN  FPTS_PPR_CBS  \
# 0          Alvin Kamara  RB   NO           21.8          21.0
# 1       Ezekiel Elliott  RB  Dal           21.1          15.0
# 2             Tom Brady  QB   NE           20.9          23.0
# 3           Todd Gurley  RB  LAR           20.9          23.0
# 4         Antonio Brown  WR  Pit           20.2          23.0
# 5      Ryan Fitzpatrick  QB   TB           19.7          20.0
# 6       Patrick Mahomes  QB   KC           19.5          23.0
# 7         David Johnson  RB  Ari           19.4          15.0
# 8        Michael Thomas  WR   NO           19.4          21.0
# 9         Aaron Rodgers  QB   GB           19.3          24.0
# 10         Carson Wentz  QB  Phi           19.2          19.0
# 11           Cam Newton  QB  Car           19.2          18.0
# 12  Christian McCaffrey  RB  Car           18.8          18.0
# 13           Alex Smith  QB  Wsh           18.7          21.0
# 14          Julio Jones  WR  Atl           18.6          19.0
# 15     Matthew Stafford  QB  Det           18.4          16.0
# 16       Saquon Barkley  RB  NYG           18.4          17.0
# 17          Dalvin Cook  RB  Min           18.2          16.0
# 18       Russell Wilson  QB  Sea           18.2          19.0
# 19   Ben Roethlisberger  QB  Pit           18.0          22.0
# 20      Jimmy Garoppolo  QB   SF           17.9          16.0
# 21      DeAndre Hopkins  WR  Hou           17.9          18.0
# 22       Deshaun Watson  QB  Hou           17.9          20.0
# 23        Odell Beckham  WR  NYG           17.8          17.0
# 24             AJ Green  WR  Cin           17.4          18.0
# 25         James Conner  RB  Pit           17.3          16.0
# 26           Drew Brees  QB   NO           17.3          20.0
# 27       Rob Gronkowski  TE   NE           17.3          20.0
# 28            Matt Ryan  QB  Atl           17.2          20.0
# 29         Keenan Allen  WR  LAC           17.2          15.0
#
#     FPTS_PPR_SHARKS  FPTS_PPR_SCOUT  FPTS_PPR_PRVS_WK_ACTUAL  PK  \
# 0              20.8            30.4                     17.9   1
# 1              20.6            20.7                     19.7   2
# 2              23.6            26.4                     16.4   3
# 3              20.9            30.5                     32.3   4
# 4              22.9            25.1                     15.7   5
# 5              20.5            25.0                     30.0   6
# 6              22.4            28.0                     38.8   7
# 7              16.0            17.9                      6.1   8
# 8              21.8            22.3                     30.9   9
# 9              21.2            25.3                     16.0  10
# 10             19.2            22.5                      0.0  11
# 11             21.1            24.1                     27.6  12
# 12             17.9            23.9                     27.9  13
# 13             22.4            22.7                     13.1  14
# 14             19.5            21.0                     11.4  15
# 15             20.3            29.1                     24.7  16
# 16             15.0            20.9                     24.8  17
# 17             13.7            22.9                     12.0  18
# 18             22.8            24.0                     14.7  19
# 19             21.6            26.0                     39.0  20
# 20             17.6            24.9                     16.6  21
# 21             18.1            22.2                     23.0  22
# 22             18.0            24.2                     22.8  23
# 23             15.0            24.3                      9.1  24
# 24             18.9            16.1                     29.9  25
# 25             20.6            27.8                     19.5  26
# 26             23.3            25.9                     17.6  27
# 27             14.7            23.0                      3.5  28
# 28             21.1            26.7                     30.7  29
# 29             16.6            18.1                     12.7  30
#
#     FPTS_PPR_CUSTOM_AVG compound_score expert_sentiment over_under  \
# 0                20.160       -0.09417        Concerned       53.5
# 1                18.165          0.296             Good       41.5
# 2                20.795     0.00398333          Neutral         52
# 3                25.160       0.123336             Good         48
# 4                20.375      -0.046625        Concerned       53.5
# 5                23.030      0.0424545             Good       53.5
# 6                27.125      0.0619618             Good         56
# 7                13.140      0.0807625             Good       37.5
# 8                23.850         0.0767             Good       53.5
# 9                20.475       0.062883             Good       45.5
# 10               13.360        Neutral          Neutral       47.5
# 11               21.525       -0.22355        Concerned       43.5
# 12               21.075       0.114318             Good       43.5
# 13               18.495         0.0852             Good       45.5
# 14               16.735          0.042             Good       53.5
# 15               19.615        Neutral          Neutral         52
# 16               19.250        -0.0594        Concerned       41.5
# 17               14.785      -0.390756        Concerned         41
# 18               18.160      0.0989636             Good       41.5
# 19               26.440       0.041513             Good       53.5
# 20               16.705       0.302833             Good         56
# 21               19.500       0.208026             Good       41.5
# 22               20.225      0.0488842             Good       41.5
# 23               14.450        0.27682             Good       41.5
# 24               21.615         0.0516             Good       43.5
# 25               17.935      0.0479846             Good       53.5
# 26               19.370       0.168067             Good       53.5
# 27               13.850        -0.4215        Concerned         52
# 28               22.955        0.03695             Good       53.5
# 29               14.880              0          Neutral         48
#
#    score_sentiment def_team_abbr week_3_proj offense_opp_def_impact
# 0          Awesome           Atl         4.1                   Good
# 1        Concerned           Sea         4.7                Neutral
# 2             Good           Det         1.5                Awesome
# 3          Neutral           LAC         4.2                   Good
# 4          Awesome            TB         3.6                   Good
# 5          Awesome           Pit         5.5                Neutral
# 6          Awesome            SF         4.6                Neutral
# 7         Terrible           Chi         6.5                Neutral
# 8          Awesome           Atl         4.1                   Good
# 9          Neutral           Wsh         6.1                Neutral
# 10         Neutral           Ind           4                   Good
# 11         Neutral           Cin         6.2                Neutral
# 12         Neutral           Cin         6.2                Neutral
# 13         Neutral            GB         4.5                Neutral
# 14         Awesome            NO         4.3                   Good
# 15            Good            NE         5.1                Neutral
# 16       Concerned           Hou         7.8                Neutral
# 17       Concerned           Buf           5                Neutral
# 18       Concerned           Dal         6.5                Neutral
# 19         Awesome            TB         3.6                   Good
# 20         Awesome            KC         6.2                Neutral
# 21       Concerned           NYG         5.4                Neutral
# 22       Concerned           NYG         5.4                Neutral
# 23       Concerned           Hou         7.8                Neutral
# 24         Neutral           Car         6.6                Neutral
# 25         Awesome            TB         3.6                   Good
# 26         Awesome           Atl         4.1                   Good
# 27            Good           Det         1.5                Awesome
# 28         Awesome            NO         4.3                   Good
# 29         Neutral           LAR         6.8                Neutral

# %%
# #apply defensive boost factor
# # def_boost = 'Full'
# # overunder_boost = 'Partial'
# # twitter_boost = 'None'

# player = 'Alvin Kamara'
# team = 'NO'
# custom_points = 20.16
# expert_sentiment = 'Concerned'
# score_sentiment = 'Good'
# defense_sentiment = 'Terrible'

# %%
def over_under_boost_calculator(row, user_boost_weight):
    #define the user's boost multiplier based on their selection of how much of the factor to apply
    if user_boost_weight == 'Full':
        user_boost_multiplier = 1.0
    elif user_boost_weight == 'Partial':
        user_boost_multiplier = 0.5
    else:
        user_boost_multiplier = 0
        
    #these are our custom boost factors based on our o/u score sentiments (can change these on the backend however we want)
    over_under_boost_values = {'Awesome': 0.2, 'Good': 0.1, 'Neutral': 0, 'Concerned': -0.1, 'Terrible': -0.2}
    
    #get the starting custom weighted average fantasy points projections by the user
    custom_points = row['FPTS_PPR_CUSTOM_AVG']
    
    #get boost multiplier based on the overunder binned sentiments and our dictionary of boost factors
    boost_multiplier = over_under_boost_values.get(row['score_sentiment'], 0)
    
    #calculate the boost points
    over_under_boost_points = custom_points * boost_multiplier * user_boost_multiplier
    
    return over_under_boost_points

# %%
def twitter_boost_calculator(row, user_boost_weight):
    #define the user's boost multiplier based on their selection of how much of the factor to apply
    if user_boost_weight == 'Full':
        user_boost_multiplier = 1.0
    elif user_boost_weight == 'Partial':
        user_boost_multiplier = 0.5
    else:
        user_boost_multiplier = 0
        
    #these are our custom boost factors based on our twitter sentiments (can change these on the backend however we want)
    twitter_boost_values = {'Awesome': 0.2, 'Good': 0.1, 'Neutral': 0, 'Concerned': -0.1, 'Terrible': -0.2}
    
    #get the starting custom weighted average fantasy points projections by the user
    custom_points = row['FPTS_PPR_CUSTOM_AVG']
    
    #get boost multiplier based on the overunder binned sentiments and our dictionary of boost factors
    boost_multiplier = twitter_boost_values.get(row['expert_sentiment'], 0)
    
    #calculate the boost points
    twitter_boost_points = custom_points * boost_multiplier * user_boost_multiplier
    
    return twitter_boost_points

# %%
def defense_boost_calculator(row, user_boost_weight):
    #if the player looking it as a Defense, we will want to skip and not boost the defense projection
    if row['POS'] == 'D/ST':
        return 0.0
    
    #otherwise apply the defense boost to all other positions (may in future want to consider removing kickers as
    #they are often unpredictable, and maybe the correlation of a harder defense is even positive on kicker points b/c they kick more FGs than TDs)
    else:
        #define the user's boost multiplier based on their selection of how much of the factor to apply
        if user_boost_weight == 'Full':
            user_boost_multiplier = 1.0
        elif user_boost_weight == 'Partial':
            user_boost_multiplier = 0.5
        else:
            user_boost_multiplier = 0

        #these are our custom boost factors based on our opposing defenses(can change these on the backend however we want)
        #the sentiment stored is from the offensive perspective of the opp def impact, so 'Good' means they 
        #are facing an easy defense and will get a positive boost, 'Terrible' means they are facing a hard 
        #defense and will get negative boost
        opp_defense_boost_values = {'Awesome': 0.2, 'Good': 0.1, 'Neutral': 0, 'Concerned': -0.1, 'Terrible': -0.2}

        #get the starting custom weighted average fantasy points projections by the user
        custom_points = row['FPTS_PPR_CUSTOM_AVG']

        #get boost multiplier based on the overunder binned sentiments and our dictionary of boost factors
        boost_multiplier = opp_defense_boost_values.get(row['offense_opp_def_impact'], 0)

        #calculate the boost points
        defense_boost_points = custom_points * boost_multiplier * user_boost_multiplier

        return defense_boost_points

# %%
print(overunder_boost_wt)
print(twitter_boost_wt)
print(def_boost_wt)
# Out:
# Partial
# None
# Full

# %%
df_boosts['OVER_UNDER_BOOST'] = df_boosts.apply(lambda row: 
                                    over_under_boost_calculator(row, overunder_boost_wt),
                                    axis='columns')

# %%
df_boosts['TWITTER_BOOST'] = df_boosts.apply(lambda row: 
                                    twitter_boost_calculator(row, twitter_boost_wt),
                                    axis='columns')

# %%
df_boosts['OPPOSING_DEFENSE_BOOST'] = df_boosts.apply(lambda row: 
                                        defense_boost_calculator(row, def_boost_wt),
                                        axis='columns')

# %%
df_boosts.head()
# Out:
#             PLAYER POS TEAM  FPTS_PPR_ESPN  FPTS_PPR_CBS  FPTS_PPR_SHARKS  \
# 0     Alvin Kamara  RB   NO           21.8          21.0             20.8
# 1  Ezekiel Elliott  RB  Dal           21.1          15.0             20.6
# 2        Tom Brady  QB   NE           20.9          23.0             23.6
# 3      Todd Gurley  RB  LAR           20.9          23.0             20.9
# 4    Antonio Brown  WR  Pit           20.2          23.0             22.9
#
#    FPTS_PPR_SCOUT  FPTS_PPR_PRVS_WK_ACTUAL  PK  FPTS_PPR_CUSTOM_AVG  \
# 0            30.4                     17.9   1               20.160
# 1            20.7                     19.7   2               18.165
# 2            26.4                     16.4   3               20.795
# 3            30.5                     32.3   4               25.160
# 4            25.1                     15.7   5               20.375
#
#   compound_score expert_sentiment over_under score_sentiment def_team_abbr  \
# 0       -0.09417        Concerned       53.5         Awesome           Atl
# 1          0.296             Good       41.5       Concerned           Sea
# 2     0.00398333          Neutral         52            Good           Det
# 3       0.123336             Good         48         Neutral           LAC
# 4      -0.046625        Concerned       53.5         Awesome            TB
#
#   week_3_proj offense_opp_def_impact  OVER_UNDER_BOOST  TWITTER_BOOST  \
# 0         4.1                   Good           2.01600           -0.0
# 1         4.7                Neutral          -0.90825            0.0
# 2         1.5                Awesome           1.03975            0.0
# 3         4.2                   Good           0.00000            0.0
# 4         3.6                   Good           2.03750           -0.0
#
#    OPPOSING_DEFENSE_BOOST
# 0                  2.0160
# 1                  0.0000
# 2                  4.1590
# 3                  2.5160
# 4                  2.0375

# %%
df_boosts.columns
# Out:
# Index(['PLAYER', 'POS', 'TEAM', 'FPTS_PPR_ESPN', 'FPTS_PPR_CBS',
#        'FPTS_PPR_SHARKS', 'FPTS_PPR_SCOUT', 'FPTS_PPR_PRVS_WK_ACTUAL', 'PK',
#        'FPTS_PPR_CUSTOM_AVG', 'compound_score', 'expert_sentiment',
#        'over_under', 'score_sentiment', 'def_team_abbr', 'week_3_proj',
#        'offense_opp_def_impact', 'OVER_UNDER_BOOST', 'TWITTER_BOOST',
#        'OPPOSING_DEFENSE_BOOST', 'FPTS_PPR_CUSTOM_AVG_BOOST'],
#       dtype='object')

# %%
#calculate final FPTS ADDING UP ALL BOOST PTS TO THE CUSTOM AVG

df_boosts['FPTS_PPR_CUSTOM_AVG_BOOST'] = df_boosts[['FPTS_PPR_CUSTOM_AVG', 'OPPOSING_DEFENSE_BOOST',
                                                    'OVER_UNDER_BOOST', 'TWITTER_BOOST']].sum(axis='columns')

# %%
df_boosts
# Out:
#                   PLAYER   POS   TEAM  FPTS_PPR_ESPN  FPTS_PPR_CBS  \
# 0           Alvin Kamara    RB     NO           21.8          21.0
# 1        Ezekiel Elliott    RB    Dal           21.1          15.0
# 2              Tom Brady    QB     NE           20.9          23.0
# 3            Todd Gurley    RB    LAR           20.9          23.0
# 4          Antonio Brown    WR    Pit           20.2          23.0
# 5       Ryan Fitzpatrick    QB     TB           19.7          20.0
# 6        Patrick Mahomes    QB     KC           19.5          23.0
# 7          David Johnson    RB    Ari           19.4          15.0
# 8         Michael Thomas    WR     NO           19.4          21.0
# 9          Aaron Rodgers    QB     GB           19.3          24.0
# 10          Carson Wentz    QB    Phi           19.2          19.0
# 11            Cam Newton    QB    Car           19.2          18.0
# 12   Christian McCaffrey    RB    Car           18.8          18.0
# 13            Alex Smith    QB    Wsh           18.7          21.0
# 14           Julio Jones    WR    Atl           18.6          19.0
# 15      Matthew Stafford    QB    Det           18.4          16.0
# 16        Saquon Barkley    RB    NYG           18.4          17.0
# 17           Dalvin Cook    RB    Min           18.2          16.0
# 18        Russell Wilson    QB    Sea           18.2          19.0
# 19    Ben Roethlisberger    QB    Pit           18.0          22.0
# 20       Jimmy Garoppolo    QB     SF           17.9          16.0
# 21       DeAndre Hopkins    WR    Hou           17.9          18.0
# 22        Deshaun Watson    QB    Hou           17.9          20.0
# 23         Odell Beckham    WR    NYG           17.8          17.0
# 24              AJ Green    WR    Cin           17.4          18.0
# 25          James Conner    RB    Pit           17.3          16.0
# 26            Drew Brees    QB     NO           17.3          20.0
# 27        Rob Gronkowski    TE     NE           17.3          20.0
# 28             Matt Ryan    QB    Atl           17.2          20.0
# 29          Keenan Allen    WR    LAC           17.2          15.0
# ..                   ...   ...    ...            ...           ...
# 327        Tyler Conklin    TE    Min            1.7           3.0
# 328         Mark Andrews    TE    Bal            1.6           3.0
# 329       Jordan Leggett    TE    NYJ            1.6           0.0
# 330            JJ Nelson    WR    Ari            1.6           4.0
# 331           CJ Prosise    RB    Sea            1.5           4.0
# 332       Tommylee Lewis    WR     NO            1.5           0.0
# 333                Lions  D/ST  Lions            1.5           6.0
# 334          Zach Pascal    WR    Ind            1.3           0.0
# 335         Justin Hardy    WR    Atl            1.3           2.0
# 336  Darrius Heyward-Bey    WR    Pit            1.2           0.0
# 337         Blake Jarwin    TE    Dal            1.1           3.0
# 338          Josh Malone    WR    Cin            1.1           0.0
# 339         David Morgan    TE    Min            1.1           2.0
# 340  James O'Shaughnessy    TE    Jax            1.0           0.0
# 341        Alex Erickson    WR    Cin            0.8           0.0
# 342           Niles Paul    TE    Jax            0.8           0.0
# 343         Dwayne Allen    TE     NE            0.7           1.0
# 344      Kendrick Bourne    WR     SF            0.7           2.0
# 345       Marcedes Lewis    TE     GB            0.6           1.0
# 346        Logan Paulsen    TE    Atl            0.6           0.0
# 347         Seth DeValve    TE    Cle            0.5           0.0
# 348         Ronald Jones    RB     TB            0.5           0.0
# 349    Wendell Smallwood    RB    Phi            0.4           1.0
# 350       Blaine Gabbert    QB    Ten            0.1           4.0
# 351        Zane Gonzalez     K    Cle            0.0           0.0
# 352       Ameer Abdullah    RB    Det            0.0           0.0
# 353       Brandon Bolden    RB    Mia            0.0           0.0
# 354        Corey Coleman    WR     NE            0.0           0.0
# 355     Aldrick Robinson    WR    Min            0.0           0.0
# 356     Cameron Meredith    WR     NO            0.0           0.0
#
#      FPTS_PPR_SHARKS  FPTS_PPR_SCOUT  FPTS_PPR_PRVS_WK_ACTUAL   PK  \
# 0               20.8            30.4                     17.9    1
# 1               20.6            20.7                     19.7    2
# 2               23.6            26.4                     16.4    3
# 3               20.9            30.5                     32.3    4
# 4               22.9            25.1                     15.7    5
# 5               20.5            25.0                     30.0    6
# 6               22.4            28.0                     38.8    7
# 7               16.0            17.9                      6.1    8
# 8               21.8            22.3                     30.9    9
# 9               21.2            25.3                     16.0   10
# 10              19.2            22.5                      0.0   11
# 11              21.1            24.1                     27.6   12
# 12              17.9            23.9                     27.9   13
# 13              22.4            22.7                     13.1   14
# 14              19.5            21.0                     11.4   15
# 15              20.3            29.1                     24.7   16
# 16              15.0            20.9                     24.8   17
# 17              13.7            22.9                     12.0   18
# 18              22.8            24.0                     14.7   19
# 19              21.6            26.0                     39.0   20
# 20              17.6            24.9                     16.6   21
# 21              18.1            22.2                     23.0   22
# 22              18.0            24.2                     22.8   23
# 23              15.0            24.3                      9.1   24
# 24              18.9            16.1                     29.9   25
# 25              20.6            27.8                     19.5   26
# 26              23.3            25.9                     17.6   27
# 27              14.7            23.0                      3.5   28
# 28              21.1            26.7                     30.7   29
# 29              16.6            18.1                     12.7   30
# ..               ...             ...                      ...  ...
# 327              0.2             1.9                      0.0  328
# 328              2.3             5.1                     10.7  329
# 329              0.9             0.8                      0.0  330
# 330              3.8             4.1                      0.0  331
# 331              3.6             3.2                      5.2  332
# 332              0.6             1.1                      0.0  333
# 333              8.2             4.5                      5.0  334
# 334              0.5             2.8                      0.0  335
# 335              3.5             1.7                      0.0  336
# 336              0.8             1.7                      0.0  337
# 337              0.4             1.9                      0.0  338
# 338              1.0             3.8                      0.0  339
# 339              1.9             0.5                      3.9  340
# 340              1.5             0.4                      2.7  341
# 341              2.2             0.2                      0.0  342
# 342              1.5             0.8                      3.2  343
# 343              1.2             2.1                      0.0  344
# 344              3.1             3.3                      7.4  345
# 345              2.0             3.0                      0.0  346
# 346              0.4             1.1                      2.0  347
# 347              1.9             3.7                      0.0  348
# 348              0.0             5.1                      0.0  349
# 349              2.2             9.3                      2.0  350
# 350              2.9            16.0                      8.9  351
# 351              1.4             6.1                      4.0  352
# 352              5.5             3.0                      0.0  353
# 353              0.2             2.0                      0.0  354
# 354              1.2             2.6                      0.0  355
# 355              2.1             1.8                      0.0  356
# 356              2.0             9.8                      0.0  357
#
#      FPTS_PPR_CUSTOM_AVG            ...             expert_sentiment  \
# 0                 20.160            ...                    Concerned
# 1                 18.165            ...                         Good
# 2                 20.795            ...                      Neutral
# 3                 25.160            ...                         Good
# 4                 20.375            ...                    Concerned
# 5                 23.030            ...                         Good
# 6                 27.125            ...                         Good
# 7                 13.140            ...                         Good
# 8                 23.850            ...                         Good
# 9                 20.475            ...                         Good
# 10                13.360            ...                      Neutral
# 11                21.525            ...                    Concerned
# 12                21.075            ...                         Good
# 13                18.495            ...                         Good
# 14                16.735            ...                         Good
# 15                19.615            ...                      Neutral
# 16                19.250            ...                    Concerned
# 17                14.785            ...                    Concerned
# 18                18.160            ...                         Good
# 19                26.440            ...                         Good
# 20                16.705            ...                         Good
# 21                19.500            ...                         Good
# 22                20.225            ...                         Good
# 23                14.450            ...                         Good
# 24                21.615            ...                         Good
# 25                17.935            ...                         Good
# 26                19.370            ...                         Good
# 27                13.850            ...                    Concerned
# 28                22.955            ...                         Good
# 29                14.880            ...                      Neutral
# ..                   ...            ...                          ...
# 327                1.485            ...                      Neutral
# 328                4.995            ...                      Neutral
# 329                0.375            ...                      Neutral
# 330                2.410            ...                      Neutral
# 331                3.925            ...                      Neutral
# 332                0.315            ...                      Neutral
# 333                5.355            ...                      Neutral
# 334                0.270            ...                      Neutral
# 335                1.520            ...                      Neutral
# 336                0.300            ...                      Neutral
# 337                1.425            ...                      Neutral
# 338                0.315            ...                      Neutral
# 339                2.420            ...                      Neutral
# 340                1.185            ...                      Neutral
# 341                0.450            ...                      Neutral
# 342                1.305            ...                      Neutral
# 343                0.685            ...                      Neutral
# 344                3.590            ...                      Neutral
# 345                0.790            ...                      Neutral
# 346                0.750            ...                      Neutral
# 347                0.360            ...                      Neutral
# 348                0.075            ...                      Neutral
# 349                1.390            ...                      Neutral
# 350                4.720            ...                      Neutral
# 351                1.410            ...                      Neutral
# 352                0.825            ...                      Neutral
# 353                0.030            ...                      Neutral
# 354                0.180            ...                      Neutral
# 355                0.315            ...                      Neutral
# 356                0.300            ...                      Neutral
#
#     over_under score_sentiment def_team_abbr week_3_proj  \
# 0         53.5         Awesome           Atl         4.1
# 1         41.5       Concerned           Sea         4.7
# 2           52            Good           Det         1.5
# 3           48         Neutral           LAC         4.2
# 4         53.5         Awesome            TB         3.6
# 5         53.5         Awesome           Pit         5.5
# 6           56         Awesome            SF         4.6
# 7         37.5        Terrible           Chi         6.5
# 8         53.5         Awesome           Atl         4.1
# 9         45.5         Neutral           Wsh         6.1
# 10        47.5         Neutral           Ind           4
# 11        43.5         Neutral           Cin         6.2
# 12        43.5         Neutral           Cin         6.2
# 13        45.5         Neutral            GB         4.5
# 14        53.5         Awesome            NO         4.3
# 15          52            Good            NE         5.1
# 16        41.5       Concerned           Hou         7.8
# 17          41       Concerned           Buf           5
# 18        41.5       Concerned           Dal         6.5
# 19        53.5         Awesome            TB         3.6
# 20          56         Awesome            KC         6.2
# 21        41.5       Concerned           NYG         5.4
# 22        41.5       Concerned           NYG         5.4
# 23        41.5       Concerned           Hou         7.8
# 24        43.5         Neutral           Car         6.6
# 25        53.5         Awesome            TB         3.6
# 26        53.5         Awesome           Atl         4.1
# 27          52            Good           Det         1.5
# 28        53.5         Awesome            NO         4.3
# 29          48         Neutral           LAR         6.8
# ..         ...             ...           ...         ...
# 327         41       Concerned           Buf           5
# 328       43.5         Neutral           Den         5.9
# 329       39.5        Terrible           Cle         7.4
# 330       37.5        Terrible           Chi         6.5
# 331       41.5       Concerned           Dal         6.5
# 332       53.5         Awesome           Atl         4.1
# 333    Neutral         Neutral       Neutral     Neutral
# 334       47.5         Neutral           Phi           7
# 335       53.5         Awesome            NO         4.3
# 336       53.5         Awesome            TB         3.6
# 337       41.5       Concerned           Sea         4.7
# 338       43.5         Neutral           Car         6.6
# 339         41       Concerned           Buf           5
# 340    Neutral         Neutral           Ten         5.2
# 341       43.5         Neutral           Car         6.6
# 342    Neutral         Neutral           Ten         5.2
# 343         52            Good           Det         1.5
# 344         56         Awesome            KC         6.2
# 345       45.5         Neutral           Wsh         6.1
# 346       53.5         Awesome            NO         4.3
# 347       39.5        Terrible           NYJ         5.2
# 348       53.5         Awesome           Pit         5.5
# 349       47.5         Neutral           Ind           4
# 350       39.5        Terrible           Jac         8.7
# 351       39.5        Terrible           NYJ         5.2
# 352         52            Good            NE         5.1
# 353       43.5         Neutral           Oak           5
# 354         52            Good           Det         1.5
# 355         41       Concerned           Buf           5
# 356       53.5         Awesome           Atl         4.1
#
#     offense_opp_def_impact OVER_UNDER_BOOST  TWITTER_BOOST  \
# 0                     Good          2.01600           -0.0
# 1                  Neutral         -0.90825            0.0
# 2                  Awesome          1.03975            0.0
# 3                     Good          0.00000            0.0
# 4                     Good          2.03750           -0.0
# 5                  Neutral          2.30300            0.0
# 6                  Neutral          2.71250            0.0
# 7                  Neutral         -1.31400            0.0
# 8                     Good          2.38500            0.0
# 9                  Neutral          0.00000            0.0
# 10                    Good          0.00000            0.0
# 11                 Neutral          0.00000           -0.0
# 12                 Neutral          0.00000            0.0
# 13                 Neutral          0.00000            0.0
# 14                    Good          1.67350            0.0
# 15                 Neutral          0.98075            0.0
# 16                 Neutral         -0.96250           -0.0
# 17                 Neutral         -0.73925           -0.0
# 18                 Neutral         -0.90800            0.0
# 19                    Good          2.64400            0.0
# 20                 Neutral          1.67050            0.0
# 21                 Neutral         -0.97500            0.0
# 22                 Neutral         -1.01125            0.0
# 23                 Neutral         -0.72250            0.0
# 24                 Neutral          0.00000            0.0
# 25                    Good          1.79350            0.0
# 26                    Good          1.93700            0.0
# 27                 Awesome          0.69250           -0.0
# 28                    Good          2.29550            0.0
# 29                 Neutral          0.00000            0.0
# ..                     ...              ...            ...
# 327                Neutral         -0.07425            0.0
# 328                Neutral          0.00000            0.0
# 329                Neutral         -0.03750            0.0
# 330                Neutral         -0.24100            0.0
# 331                Neutral         -0.19625            0.0
# 332                   Good          0.03150            0.0
# 333                Neutral          0.00000            0.0
# 334                Neutral          0.00000            0.0
# 335                   Good          0.15200            0.0
# 336                   Good          0.03000            0.0
# 337                Neutral         -0.07125            0.0
# 338                Neutral          0.00000            0.0
# 339                Neutral         -0.12100            0.0
# 340                Neutral          0.00000            0.0
# 341                Neutral          0.00000            0.0
# 342                Neutral          0.00000            0.0
# 343                Awesome          0.03425            0.0
# 344                Neutral          0.35900            0.0
# 345                Neutral          0.00000            0.0
# 346                   Good          0.07500            0.0
# 347                Neutral         -0.03600            0.0
# 348                Neutral          0.00750            0.0
# 349                   Good          0.00000            0.0
# 350              Concerned         -0.47200            0.0
# 351                Neutral         -0.14100            0.0
# 352                Neutral          0.04125            0.0
# 353                Neutral          0.00000            0.0
# 354                Awesome          0.00900            0.0
# 355                Neutral         -0.01575            0.0
# 356                   Good          0.03000            0.0
#
#      OPPOSING_DEFENSE_BOOST  FPTS_PPR_CUSTOM_AVG_BOOST
# 0                    2.0160                   24.19200
# 1                    0.0000                   17.25675
# 2                    4.1590                   25.99375
# 3                    2.5160                   27.67600
# 4                    2.0375                   24.45000
# 5                    0.0000                   25.33300
# 6                    0.0000                   29.83750
# 7                    0.0000                   11.82600
# 8                    2.3850                   28.62000
# 9                    0.0000                   20.47500
# 10                   1.3360                   14.69600
# 11                   0.0000                   21.52500
# 12                   0.0000                   21.07500
# 13                   0.0000                   18.49500
# 14                   1.6735                   20.08200
# 15                   0.0000                   20.59575
# 16                   0.0000                   18.28750
# 17                   0.0000                   14.04575
# 18                   0.0000                   17.25200
# 19                   2.6440                   31.72800
# 20                   0.0000                   18.37550
# 21                   0.0000                   18.52500
# 22                   0.0000                   19.21375
# 23                   0.0000                   13.72750
# 24                   0.0000                   21.61500
# 25                   1.7935                   21.52200
# 26                   1.9370                   23.24400
# 27                   2.7700                   17.31250
# 28                   2.2955                   27.54600
# 29                   0.0000                   14.88000
# ..                      ...                        ...
# 327                  0.0000                    1.41075
# 328                  0.0000                    4.99500
# 329                  0.0000                    0.33750
# 330                  0.0000                    2.16900
# 331                  0.0000                    3.72875
# 332                  0.0315                    0.37800
# 333                  0.0000                    5.35500
# 334                  0.0000                    0.27000
# 335                  0.1520                    1.82400
# 336                  0.0300                    0.36000
# 337                  0.0000                    1.35375
# 338                  0.0000                    0.31500
# 339                  0.0000                    2.29900
# 340                  0.0000                    1.18500
# 341                  0.0000                    0.45000
# 342                  0.0000                    1.30500
# 343                  0.1370                    0.85625
# 344                  0.0000                    3.94900
# 345                  0.0000                    0.79000
# 346                  0.0750                    0.90000
# 347                  0.0000                    0.32400
# 348                  0.0000                    0.08250
# 349                  0.1390                    1.52900
# 350                 -0.4720                    3.77600
# 351                  0.0000                    1.26900
# 352                  0.0000                    0.86625
# 353                  0.0000                    0.03000
# 354                  0.0360                    0.22500
# 355                  0.0000                    0.29925
# 356                  0.0300                    0.36000
#
# [357 rows x 21 columns]

# %%
#reorder dataframe and limits columns for the final output data and sort descending by custom poitns
df_boosts_output = df_boosts[['PLAYER', 'POS', 'TEAM', 'FPTS_PPR_CUSTOM_AVG_BOOST',
                              'FPTS_PPR_ESPN', 'FPTS_PPR_CBS', 'FPTS_PPR_SHARKS', 'FPTS_PPR_SCOUT',
                              'FPTS_PPR_PRVS_WK_ACTUAL', 'FPTS_PPR_CUSTOM_AVG', 
                              'OVER_UNDER_BOOST', 'TWITTER_BOOST',
                              'OPPOSING_DEFENSE_BOOST']].sort_values('FPTS_PPR_CUSTOM_AVG_BOOST',
                                                                    ascending=False)

# %%
df_boosts_output
# Out:
#                   PLAYER POS TEAM  FPTS_PPR_CUSTOM_AVG_BOOST  FPTS_PPR_ESPN  \
# 19    Ben Roethlisberger  QB  Pit                   31.72800           18.0
# 6        Patrick Mahomes  QB   KC                   29.83750           19.5
# 8         Michael Thomas  WR   NO                   28.62000           19.4
# 3            Todd Gurley  RB  LAR                   27.67600           20.9
# 28             Matt Ryan  QB  Atl                   27.54600           17.2
# 2              Tom Brady  QB   NE                   25.99375           20.9
# 5       Ryan Fitzpatrick  QB   TB                   25.33300           19.7
# 52   JuJu Smith-Schuster  WR  Pit                   25.30800           14.5
# 4          Antonio Brown  WR  Pit                   24.45000           20.2
# 0           Alvin Kamara  RB   NO                   24.19200           21.8
# 31          Kirk Cousins  QB  Min                   23.40325           16.7
# 26            Drew Brees  QB   NO                   23.24400           17.3
# 47         Blake Bortles  QB  Jax                   22.79000           15.1
# 24              AJ Green  WR  Cin                   21.61500           17.4
# 11            Cam Newton  QB  Car                   21.52500           19.2
# 25          James Conner  RB  Pit                   21.52200           17.3
# 12   Christian McCaffrey  RB  Car                   21.07500           18.8
# 57          Travis Kelce  TE   KC                   20.89450           13.9
# 63          Stefon Diggs  WR  Min                   20.83825           13.6
# 15      Matthew Stafford  QB  Det                   20.59575           18.4
# 9          Aaron Rodgers  QB   GB                   20.47500           19.3
# 14           Julio Jones  WR  Atl                   20.08200           18.6
# 54         Melvin Gordon  RB  LAC                   19.74000           14.2
# 33           Andy Dalton  QB  Cin                   19.73500           16.5
# 42            Mike Evans  WR   TB                   19.53600           15.8
# 41            Jared Goff  QB  LAR                   19.32150           16.1
# 22        Deshaun Watson  QB  Hou                   19.21375           17.9
# 37           Tyreek Hill  WR   KC                   19.14000           16.4
# 45          Adam Thielen  WR  Min                   18.73875           15.3
# 21       DeAndre Hopkins  WR  Hou                   18.52500           17.9
# ..                   ...  ..  ...                        ...            ...
# 314    De'Anthony Thomas  WR   KC                    1.68850            2.3
# 305         Ryan Switzer  WR  Pit                    1.63800            2.9
# 349    Wendell Smallwood  RB  Phi                    1.52900            0.4
# 327        Tyler Conklin  TE  Min                    1.41075            1.7
# 271         Andre Holmes  WR  Buf                    1.37625            4.5
# 337         Blake Jarwin  TE  Dal                    1.35375            1.1
# 342           Niles Paul  TE  Jax                    1.30500            0.8
# 351        Zane Gonzalez   K  Cle                    1.26900            0.0
# 267       Shelton Gibson  WR  Phi                    1.25400            4.7
# 340  James O'Shaughnessy  TE  Jax                    1.18500            1.0
# 310     Jonathan Stewart  RB  NYG                    1.14000            2.6
# 325      Lance Kendricks  TE   GB                    0.96000            1.7
# 322      Damien Williams  RB   KC                    0.90750            1.8
# 346        Logan Paulsen  TE  Atl                    0.90000            0.6
# 352       Ameer Abdullah  RB  Det                    0.86625            0.0
# 343         Dwayne Allen  TE   NE                    0.85625            0.7
# 345       Marcedes Lewis  TE   GB                    0.79000            0.6
# 302            Dion Sims  TE  Chi                    0.78300            3.0
# 341        Alex Erickson  WR  Cin                    0.45000            0.8
# 332       Tommylee Lewis  WR   NO                    0.37800            1.5
# 356     Cameron Meredith  WR   NO                    0.36000            0.0
# 336  Darrius Heyward-Bey  WR  Pit                    0.36000            1.2
# 329       Jordan Leggett  TE  NYJ                    0.33750            1.6
# 347         Seth DeValve  TE  Cle                    0.32400            0.5
# 338          Josh Malone  WR  Cin                    0.31500            1.1
# 355     Aldrick Robinson  WR  Min                    0.29925            0.0
# 334          Zach Pascal  WR  Ind                    0.27000            1.3
# 354        Corey Coleman  WR   NE                    0.22500            0.0
# 348         Ronald Jones  RB   TB                    0.08250            0.5
# 353       Brandon Bolden  RB  Mia                    0.03000            0.0
#
#      FPTS_PPR_CBS  FPTS_PPR_SHARKS  FPTS_PPR_SCOUT  FPTS_PPR_PRVS_WK_ACTUAL  \
# 19           22.0             21.6            26.0                     39.0
# 6            23.0             22.4            28.0                     38.8
# 8            21.0             21.8            22.3                     30.9
# 3            23.0             20.9            30.5                     32.3
# 28           20.0             21.1            26.7                     30.7
# 2            23.0             23.6            26.4                     16.4
# 5            20.0             20.5            25.0                     30.0
# 52           18.0             15.9            22.7                     31.1
# 4            23.0             22.9            25.1                     15.7
# 0            21.0             20.8            30.4                     17.9
# 31           23.0             19.2            23.5                     33.5
# 26           20.0             23.3            25.9                     17.6
# 47           20.0             18.3            23.2                     32.6
# 24           18.0             18.9            16.1                     29.9
# 11           18.0             21.1            24.1                     27.6
# 25           16.0             20.6            27.8                     19.5
# 12           18.0             17.9            23.9                     27.9
# 57           14.0             15.6            15.2                     29.9
# 63           17.0             15.5            17.0                     35.9
# 15           16.0             20.3            29.1                     24.7
# 9            24.0             21.2            25.3                     16.0
# 14           19.0             19.5            21.0                     11.4
# 54           15.0             16.2            22.1                     30.6
# 33           16.0             19.2            22.5                     26.6
# 42           15.0             18.0            18.5                     22.3
# 41           18.0             16.2            25.6                     18.4
# 22           20.0             18.0            24.2                     22.8
# 37           15.0             19.6            20.4                     20.0
# 45           15.0             14.0            17.7                     31.1
# 21           18.0             18.1            22.2                     23.0
# ..            ...              ...             ...                      ...
# 314           2.0              2.6             1.2                      0.0
# 305           0.0              0.4             2.0                      2.9
# 349           1.0              2.2             9.3                      2.0
# 327           3.0              0.2             1.9                      0.0
# 271           2.0              2.4             5.0                      0.0
# 337           3.0              0.4             1.9                      0.0
# 342           0.0              1.5             0.8                      3.2
# 351           0.0              1.4             6.1                      4.0
# 267           0.0              2.9             5.9                      0.0
# 340           0.0              1.5             0.4                      2.7
# 310           0.0              5.2             0.8                      0.1
# 325           0.0              1.9             0.6                      1.4
# 322           0.0              1.3             1.1                      1.2
# 346           0.0              0.4             1.1                      2.0
# 352           0.0              5.5             3.0                      0.0
# 343           1.0              1.2             2.1                      0.0
# 345           1.0              2.0             3.0                      0.0
# 302           0.0              2.8             1.0                      0.0
# 341           0.0              2.2             0.2                      0.0
# 332           0.0              0.6             1.1                      0.0
# 356           0.0              2.0             9.8                      0.0
# 336           0.0              0.8             1.7                      0.0
# 329           0.0              0.9             0.8                      0.0
# 347           0.0              1.9             3.7                      0.0
# 338           0.0              1.0             3.8                      0.0
# 355           0.0              2.1             1.8                      0.0
# 334           0.0              0.5             2.8                      0.0
# 354           0.0              1.2             2.6                      0.0
# 348           0.0              0.0             5.1                      0.0
# 353           0.0              0.2             2.0                      0.0
#
#      FPTS_PPR_CUSTOM_AVG  OVER_UNDER_BOOST  TWITTER_BOOST  \
# 19                26.440           2.64400            0.0
# 6                 27.125           2.71250            0.0
# 8                 23.850           2.38500            0.0
# 3                 25.160           0.00000            0.0
# 28                22.955           2.29550            0.0
# 2                 20.795           1.03975            0.0
# 5                 23.030           2.30300            0.0
# 52                21.090           2.10900           -0.0
# 4                 20.375           2.03750           -0.0
# 0                 20.160           2.01600           -0.0
# 31                24.635          -1.23175            0.0
# 26                19.370           1.93700            0.0
# 47                22.790           0.00000            0.0
# 24                21.615           0.00000            0.0
# 11                21.525           0.00000           -0.0
# 25                17.935           1.79350            0.0
# 12                21.075           0.00000            0.0
# 57                18.995           1.89950           -0.0
# 63                21.935          -1.09675            0.0
# 15                19.615           0.98075            0.0
# 9                 20.475           0.00000            0.0
# 14                16.735           1.67350            0.0
# 54                19.740           0.00000            0.0
# 33                19.735           0.00000            0.0
# 42                17.760           1.77600           -0.0
# 41                17.565           0.00000            0.0
# 22                20.225          -1.01125            0.0
# 37                17.400           1.74000            0.0
# 45                19.725          -0.98625            0.0
# 21                19.500          -0.97500            0.0
# ..                   ...               ...            ...
# 314                1.535           0.15350            0.0
# 305                1.365           0.13650            0.0
# 349                1.390           0.00000            0.0
# 327                1.485          -0.07425            0.0
# 271                1.835          -0.09175            0.0
# 337                1.425          -0.07125            0.0
# 342                1.305           0.00000            0.0
# 351                1.410          -0.14100            0.0
# 267                1.140           0.00000            0.0
# 340                1.185           0.00000            0.0
# 310                1.200          -0.06000            0.0
# 325                0.960           0.00000            0.0
# 322                0.825           0.08250            0.0
# 346                0.750           0.07500            0.0
# 352                0.825           0.04125            0.0
# 343                0.685           0.03425            0.0
# 345                0.790           0.00000            0.0
# 302                0.870          -0.08700            0.0
# 341                0.450           0.00000            0.0
# 332                0.315           0.03150            0.0
# 356                0.300           0.03000            0.0
# 336                0.300           0.03000            0.0
# 329                0.375          -0.03750            0.0
# 347                0.360          -0.03600            0.0
# 338                0.315           0.00000            0.0
# 355                0.315          -0.01575            0.0
# 334                0.270           0.00000            0.0
# 354                0.180           0.00900            0.0
# 348                0.075           0.00750            0.0
# 353                0.030           0.00000            0.0
#
#      OPPOSING_DEFENSE_BOOST
# 19                   2.6440
# 6                    0.0000
# 8                    2.3850
# 3                    2.5160
# 28                   2.2955
# 2                    4.1590
# 5                    0.0000
# 52                   2.1090
# 4                    2.0375
# 0                    2.0160
# 31                   0.0000
# 26                   1.9370
# 47                   0.0000
# 24                   0.0000
# 11                   0.0000
# 25                   1.7935
# 12                   0.0000
# 57                   0.0000
# 63                   0.0000
# 15                   0.0000
# 9                    0.0000
# 14                   1.6735
# 54                   0.0000
# 33                   0.0000
# 42                   0.0000
# 41                   1.7565
# 22                   0.0000
# 37                   0.0000
# 45                   0.0000
# 21                   0.0000
# ..                      ...
# 314                  0.0000
# 305                  0.1365
# 349                  0.1390
# 327                  0.0000
# 271                 -0.3670
# 337                  0.0000
# 342                  0.0000
# 351                  0.0000
# 267                  0.1140
# 340                  0.0000
# 310                  0.0000
# 325                  0.0000
# 322                  0.0000
# 346                  0.0750
# 352                  0.0000
# 343                  0.1370
# 345                  0.0000
# 302                  0.0000
# 341                  0.0000
# 332                  0.0315
# 356                  0.0300
# 336                  0.0300
# 329                  0.0000
# 347                  0.0000
# 338                  0.0000
# 355                  0.0000
# 334                  0.0000
# 354                  0.0360
# 348                  0.0000
# 353                  0.0000
#
# [357 rows x 13 columns]

# %%
df_tweets.columns
# Out:
# Index(['Unnamed: 0', 'number', 'player', 'compound_score', 'binned',
#        'expert_sentiment', 'color', 'all_tweets'],
#       dtype='object')

# %%
df_overunder2 = pd.DataFrame(columns=['Unnamed: 0', 'team', 'over_under', 'team_abbr', 'binned',
       'score_sentiment'])

# %%
df_overunder2
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, team, over_under, team_abbr, binned, score_sentiment]
# Index: []

# %% [markdown]
# ##### Converting Our DF to a JSON File
# ##### !!!Don't use .to_json it makes it all a string, better way is use .to_dict('records')
#
# Note: when you return the json in flask, you'll also want to jsonify it to make sure it is formatted well.  return jsonify(json)

# %%
#create json that is a list of dictionaries, where each row is its own dictionary with column:value pairs
df_week1_ppr_projections.head(10).to_json('filename_test', orient='records')

# %%
json_test = df_week1_ppr_projections.head(10).to_json(orient='records')
jsonfiles = json.loads(json_test)

jsonfiles
# Out:
# [{'PLAYER': 'Alvin Kamara',
#   'POS': 'RB',
#   'TEAM': 'NO',
#   'FPTS_PPR_ESPN': 22.2,
#   'FPTS_PPR_CBS': 19.0,
#   'FPTS_PPR_SHARKS': 19.1,
#   'FPTS_PPR_SCOUT': 34.0,
#   'FPTS_PPR_PRVS_WK_ACTUAL': 0.0,
#   'PK': 1},
#  {'PLAYER': 'David Johnson',
#   'POS': 'RB',
#   'TEAM': 'Ari',
#   'FPTS_PPR_ESPN': 21.3,
#   'FPTS_PPR_CBS': 19.0,
#   'FPTS_PPR_SHARKS': 23.6,
#   'FPTS_PPR_SCOUT': 27.0,
#   'FPTS_PPR_PRVS_WK_ACTUAL': 0.0,
#   'PK': 2},
#  {'PLAYER': 'Todd Gurley',
#   'POS': 'RB',
#   'TEAM': 'LAR',
#   'FPTS_PPR_ESPN': 21.2,
#   'FPTS_PPR_CBS': 23.0,
#   'FPTS_PPR_SHARKS': 19.3,
#   'FPTS_PPR_SCOUT': 28.5,
#   'FPTS_PPR_PRVS_WK_ACTUAL': 0.0,
#   'PK': 3},
#  {'PLAYER': 'Antonio Brown',
#   'POS': 'WR',
#   'TEAM': 'Pit',
#   'FPTS_PPR_ESPN': 19.5,
#   'FPTS_PPR_CBS': 22.0,
#   'FPTS_PPR_SHARKS': 19.3,
#   'FPTS_PPR_SCOUT': 17.3,
#   'FPTS_PPR_PRVS_WK_ACTUAL': 0.0,
#   'PK': 4},
#  {'PLAYER': 'Tom Brady',
#   'POS': 'QB',
#   'TEAM': 'NE',
#   'FPTS_PPR_ESPN': 19.4,
#   'FPTS_PPR_CBS': 20.0,
#   'FPTS_PPR_SHARKS': 27.4,
#   'FPTS_PPR_SCOUT': 23.3,
#   'FPTS_PPR_PRVS_WK_ACTUAL': 0.0,
#   'PK': 5},
#  {'PLAYER': 'Aaron Rodgers',
#   'POS': 'QB',
#   'TEAM': 'GB',
#   'FPTS_PPR_ESPN': 19.0,
#   'FPTS_PPR_CBS': 22.0,
#   'FPTS_PPR_SHARKS': 22.4,
#   'FPTS_PPR_SCOUT': 27.1,
#   'FPTS_PPR_PRVS_WK_ACTUAL': 0.0,
#   'PK': 6},
#  {'PLAYER': 'Cam Newton',
#   'POS': 'QB',
#   'TEAM': 'Car',
#   'FPTS_PPR_ESPN': 18.7,
#   'FPTS_PPR_CBS': 17.0,
#   'FPTS_PPR_SHARKS': 21.4,
#   'FPTS_PPR_SCOUT': 24.2,
#   'FPTS_PPR_PRVS_WK_ACTUAL': 0.0,
#   'PK': 7},
#  {'PLAYER': 'Andrew Luck',
#   'POS': 'QB',
#   'TEAM': 'Ind',
#   'FPTS_PPR_ESPN': 18.4,
#   'FPTS_PPR_CBS': 20.0,
#   'FPTS_PPR_SHARKS': 21.1,
#   'FPTS_PPR_SCOUT': 23.7,
#   'FPTS_PPR_PRVS_WK_ACTUAL': 0.0,
#   'PK': 8},
#  {'PLAYER': 'Ezekiel Elliott',
#   'POS': 'RB',
#   'TEAM': 'Dal',
#   'FPTS_PPR_ESPN': 18.4,
#   'FPTS_PPR_CBS': 15.0,
#   'FPTS_PPR_SHARKS': 18.9,
#   'FPTS_PPR_SCOUT': 23.0,
#   'FPTS_PPR_PRVS_WK_ACTUAL': 0.0,
#   'PK': 9},
#  {'PLAYER': 'DeAndre Hopkins',
#   'POS': 'WR',
#   'TEAM': 'Hou',
#   'FPTS_PPR_ESPN': 18.2,
#   'FPTS_PPR_CBS': 22.0,
#   'FPTS_PPR_SHARKS': 16.4,
#   'FPTS_PPR_SCOUT': 23.6,
#   'FPTS_PPR_PRVS_WK_ACTUAL': 0.0,
#   'PK': 10}]

# %%
jsonify(json)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-51-7c024d96effd> in <module>()
# ----> 1 jsonify(json)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\flask\json\__init__.py in jsonify(*args, **kwargs)
#     307     separators = (',', ':')
#     308
# --> 309     if current_app.config['JSONIFY_PRETTYPRINT_REGULAR'] or current_app.debug:
#     310         indent = 2
#     311         separators = (', ', ': ')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\werkzeug\local.py in __getattr__(self, name)
#     345         if name == '__members__':
#     346             return dir(self._get_current_object())
# --> 347         return getattr(self._get_current_object(), name)
#     348
#     349     def __setitem__(self, key, value):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\werkzeug\local.py in _get_current_object(self)
#     304         """
#     305         if not hasattr(self.__local, '__release_local__'):
# --> 306             return self.__local()
#     307         try:
#     308             return getattr(self.__local, self.__name__)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\flask\globals.py in _find_app()
#      49     top = _app_ctx_stack.top
#      50     if top is None:
# ---> 51         raise RuntimeError(_app_ctx_err_msg)
#      52     return top.app
#      53
#
# RuntimeError: Working outside of application context.
#
# This typically means that you attempted to use functionality that needed
# to interface with the current application object in some way. To solve
# this, set up an application context with app.app_context().  See the
# documentation for more information.
