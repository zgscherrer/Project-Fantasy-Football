# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tweepy
import json
from config import (consumer_key, consumer_secret, 
                    access_token, access_token_secret)
from datetime import datetime, timedelta, timezone
import time

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
ffb_twitters = ['@Rotoworld_FB', '@AdamSchefter', '@sn_fantasy', '@FantasyADHD', '@PFF_Fantasy', '@FantasyPros', 
                '@MatthewBerryTMR', '@Stephania_ESPN', '@FieldYates', '@karabelleric', '@SultanofStat', 
                '@MattWaldman', '@ProFootballDoc', '@espn', '@darrenrovell', '@MattFtheOracle', '@The_Oddsmaker', 
                '@ChrisRaybon', '@FantasyLabsNFL', '@AdamLevitan', '@CSURAM88', '@BalesFootball', '@EvanSilva',
                '@LordReebs', '@GrahamBarfield', '@MattHarmon_BYB', '@CFrelund', '@ThePowerRank', '@Cole_Kev', 
                '@FriscoJosh', '@Fantasy_Mansion', '@BrandonHerFFB', '@FBallGameplan', '@ScottBarrettDFB', '@RyanMc23',
                '@MikeTagliereNFL', '@LateRoundQB', '@CDCarter13', '@LizLoza_FF', '@HarrisFootball']

# %%
#for loop to collect all tweet data from each fantasy twitter handle
merged_tweets = []
tweet_count = []

for x in ffb_twitters:
    num_tweets = 0
    for status in tweepy.Cursor(api.user_timeline, id=x).items(300):
        merged_tweets.append(status)
        num_tweets += 1
        tweet_count.append(num_tweets)

# %%
#organize tweets into a data frame
df = pd.DataFrame([x._json for x in merged_tweets])[['text', 'created_at', 'user']]
df['label'] = df.user.map(lambda x: x.get('name'))
df['tweet_count'] = tweet_count
df.head()
# Out:
#                                                 text  \
# 0  Bills surprisingly part ways with WR Kerley ht...
# 1  #NFL Week 2 Injury Report: Checking in on Leon...
# 2  #NFL Narratives: @JessePantuosco highlights Ma...
# 3  Despite his lack of production in Week 1, Trav...
# 4  RT @RotoPat: Lots of injury updates to the ran...
#
#                        created_at  \
# 0  Sat Sep 15 16:09:45 +0000 2018
# 1  Sat Sep 15 15:22:05 +0000 2018
# 2  Sat Sep 15 14:19:05 +0000 2018
# 3  Sat Sep 15 12:00:24 +0000 2018
# 4  Fri Sep 14 22:06:40 +0000 2018
#
#                                                 user               label  \
# 0  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
# 1  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
# 2  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
# 3  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
# 4  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
#
#    tweet_count
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5

# %%
#double checking total tweet count to make sure we have all the data
df.describe()
# df.to_pickle(df)
# Out:
#         tweet_count
# count  12000.000000
# mean     150.500000
# std       86.605668
# min        1.000000
# 25%       75.750000
# 50%      150.500000
# 75%      225.250000
# max      300.000000

# %%
analyzer = SentimentIntensityAnalyzer() # Initialize the class

# %%
merged_text = [x._json['text'] for x in merged_tweets]

# %%
#running vader analysis for all tweets
compound_list = []
positive_list = []
negative_list = []
neutral_list = []

for tweet in merged_text:
    vs = analyzer.polarity_scores(tweet)
    compound_list.append(vs.get('compound'))
    positive_list.append(vs.get('pos'))
    negative_list.append(vs.get('neg'))
    neutral_list.append(vs.get('neu'))

# %%
#adding vader scores to the df
df['compound_score'] = compound_list
df['positive_score'] = positive_list
df['negative_score'] = negative_list
df['neutral_score'] = neutral_list
df.head()
# Out:
#                                                 text  \
# 0  Bills surprisingly part ways with WR Kerley ht...
# 1  #NFL Week 2 Injury Report: Checking in on Leon...
# 2  #NFL Narratives: @JessePantuosco highlights Ma...
# 3  Despite his lack of production in Week 1, Trav...
# 4  RT @RotoPat: Lots of injury updates to the ran...
#
#                        created_at  \
# 0  Sat Sep 15 16:09:45 +0000 2018
# 1  Sat Sep 15 15:22:05 +0000 2018
# 2  Sat Sep 15 14:19:05 +0000 2018
# 3  Sat Sep 15 12:00:24 +0000 2018
# 4  Fri Sep 14 22:06:40 +0000 2018
#
#                                                 user               label  \
# 0  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
# 1  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
# 2  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
# 3  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
# 4  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
#
#    tweet_count  compound_score  positive_score  negative_score  neutral_score
# 0            1          0.2960           0.239           0.000          0.761
# 1            2         -0.4215           0.000           0.157          0.843
# 2            3         -0.7506           0.000           0.348          0.652
# 3            4         -0.0258           0.086           0.090          0.824
# 4            5         -0.0258           0.110           0.114          0.776

# %%
elliot_df = df[df['text'].str.contains("Elliot")]
elliot_df.head()
# Out:
#                                                    text  \
# 2539                @Elliot_Solop From @vineyardvines !
# 4432                                   @BudElliott3 😂😂😂
# 4629  RT @DraftKings: WATCH: How are Ezekiel Elliott...
# 7224  Ezekiel Elliott’s continued his encouraging pa...
# 7434  Ezekiel Elliott’s routes run per game spiked l...
#
#                           created_at  \
# 2539  Sun Sep 09 15:52:16 +0000 2018
# 4432  Fri Sep 07 17:53:23 +0000 2018
# 4629  Fri Aug 24 16:58:48 +0000 2018
# 7224  Mon Sep 10 14:40:57 +0000 2018
# 7434  Wed Aug 01 23:05:35 +0000 2018
#
#                                                    user             label  \
# 2539  {'id': 58919137, 'id_str': '58919137', 'name':...       Field Yates
# 4432  {'id': 24277551, 'id_str': '24277551', 'name':...     Darren Rovell
# 4629  {'id': 1265991506, 'id_str': '1265991506', 'na...  Matthew Freedman
# 7224  {'id': 1852555963, 'id_str': '1852555963', 'na...   Graham Barfield
# 7434  {'id': 1852555963, 'id_str': '1852555963', 'na...   Graham Barfield
#
#       tweet_count  compound_score  positive_score  negative_score  \
# 2539          140          0.0000           0.000           0.000
# 4432          233          0.0000           0.000           0.000
# 4629          130         -0.5574           0.000           0.204
# 7224           25          0.7003           0.279           0.000
# 7434          235          0.0000           0.000           0.000
#
#       neutral_score
# 2539          1.000
# 4432          1.000
# 4629          0.796
# 7224          0.721
# 7434          1.000

# %%
elliot_df['text'].tolist()
# Out:
# ['@Elliot_Solop From @vineyardvines !',
#  '@BudElliott3 😂😂😂',
#  "RT @DraftKings: WATCH: How are Ezekiel Elliott &amp; Dak Prescott affected by injuries to the Cowboys' offensive line? \n\n@dklive's @reidtfowler…",
#  'Ezekiel Elliott’s continued his encouraging pass-down involvement in Week 1 for #Cowboys. Elliott played on 92% of… https://t.co/LcxwyNKlrR',
#  'Ezekiel Elliott’s routes run per game spiked last year (26.7) compared to his rookie season (17.6). In fact, Zeke r… https://t.co/A7rPKhhrS2',
#  'RT @BudElliott3: Abdul Bello.\n\nFSU is now without Landon Dickerson, Cole Minshew, and Derrick Kelly and they are in big trouble because tac…',
#  'RT @SBRSportsPicks: Saturday Morning at the #IFBC2018: @SBN_BillC, @BudElliott3 &amp; @thepowerrank sat down with @DrewMartinBets to preview #C…',
#  'RT @SBRSportsPicks: Getting ready to go LIVE! \n@thepowerrank @SBN_BillC @BudElliott3 &amp; @DrewMartinBets are waiting to present at #IFBC2018…',
#  'Over/Under 19.5 Adrian Peterson Rush Attempts?\nOver/Under 30.5 Zeke Elliott Touches?\nOver/Under 3.5 Times… https://t.co/ublYt63Mfw']

# %%
#getting average sentiment score for a player
elliot_df.get('compound_score').mean()
# Out:
# 0.017877777777777784

# %%
matt_df = df[df['text'].str.contains('Stafford')]
matt_df.head()
# Out:
#                                                    text  \
# 215   Stafford melts down with 4 INTs against Jets h...
# 1599  Even Matthew Stafford thinks Derek Carr just t...
# 1615  Matthew Stafford has robbed us all of #Jets jo...
# 1894  Stafford was off but Jets D is legit. https://...
# 1897  For those of you with Stafford at QB... https:...
#
#                           created_at  \
# 215   Tue Sep 11 02:15:12 +0000 2018
# 1599  Tue Sep 11 05:07:29 +0000 2018
# 1615  Tue Sep 11 01:22:00 +0000 2018
# 1894  Tue Sep 11 02:23:13 +0000 2018
# 1897  Tue Sep 11 01:37:50 +0000 2018
#
#                                                    user               label  \
# 215   {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
# 1599  {'id': 185125451, 'id_str': '185125451', 'name...         FantasyPros
# 1615  {'id': 185125451, 'id_str': '185125451', 'name...         FantasyPros
# 1894  {'id': 20899023, 'id_str': '20899023', 'name':...       Matthew Berry
# 1897  {'id': 20899023, 'id_str': '20899023', 'name':...       Matthew Berry
#
#       tweet_count  compound_score  positive_score  negative_score  \
# 215           216          0.0000           0.000           0.000
# 1599          100         -0.5423           0.000           0.259
# 1615          116          0.2500           0.154           0.000
# 1894           95          0.0000           0.000           0.000
# 1897           98          0.0000           0.000           0.000
#
#       neutral_score
# 215           1.000
# 1599          0.741
# 1615          0.846
# 1894          1.000
# 1897          1.000

# %%
matt_df.get('compound_score').mean()
# Out:
# 0.10738965517241379

# %%
bell_df = df[df['text'].str.contains("Le'Veon Bell")]
bell_df
# Out:
#                                                     text  \
# 38     "Gotta be honest, I think Le'Veon Bell is goin...
# 166    Le'Veon Bell not with Steelers on Wednesday ht...
# 300    It's just after noon, and there's no sign of R...
# 421    To anyone suggesting the Steelers trade RB Le'...
# 435    The 4 p.m. deadline today will come and go wit...
# 469    RT @FieldYates: Le'Veon Bell's agent Adisa Bak...
# 470    The latest on Le'Veon Bell. https://t.co/Timql...
# 476    RT @RossTuckerNFL: From a strictly business pe...
# 505    No Le’Veon Bell, still.\n\nSteelers GM Kevin C...
# 652    Fantasy Football Updates: Greg Olsen, Le'Veon ...
# 658    Fantasy Football Updates: Carson Wentz, Devont...
# 666    Our Week 1 #FantasyFootball podcast hits all t...
# 672    Fantasy Football Updates: Le'Veon Bell holdout...
# 698    Our take on Le'Veon Bell and James Conner. Cou...
# 719    Fantasy Football Updates: Le'Veon Bell holdout...
# 808    Fantasy Football Updates: Josh Gordon injury, ...
# 853    Fantasy Football Updates: Le'Veon Bell holdout...
# 863    Le'Veon Bell is expected to report on Monday. ...
# 1121   My guess is that PIT knows this (or at least s...
# 1168   With Le'Veon Bell opting out of another week's...
# 1303   Even if James Conner doesn't have all of Le'Ve...
# 1571   RT @nfl_alerts: Le'Veon Bell still not present...
# 1671   Le'Veon Bell has a big problem. James Conner i...
# 1759   RT @nfl_alerts: Le'Veon Bell could report to S...
# 1784   RT @nfl_alerts: Le'Veon Bell could miss 'sever...
# 1790   RT @nfl_alerts: Le'Veon Bell not at Steelers' ...
# 1988   RT @ESPNFantasy: How much can you rely on Jame...
# 2454   Le'Veon Bell was removed from the Steelers dep...
# 2501   After a monster game in Week 1, James Conner h...
# 2535   Filling in for Le'Veon Bell, James Conner scor...
# 2598   All the Le'Veon Bell analysis, a game preview ...
# 2616   Le'Veon Bell's agent Adisa Bakari just now on ...
# 2632   Le'Veon Bell has not yet reported to the Steel...
# 2657   From Week 1 QB options to the impact of Le'Veo...
# 2746   RT @AndrewBrandt: For all this current animus,...
# 3212   The overwhelming consensus was to wait on QB. ...
# 4063   It's been 114 days since Le'Veon Bell tweeted ...
# 4932   If you are drafting today, what Round would yo...
# 5400   Le'Veon Bell still absent from Steelers' train...
# 5616   Le'Veon Bell still absent from Steelers’ train...
# 5633   Le'Veon Bell not included in Week 2 depth char...
# 5801   James Conner had 38.2 DK points today in his f...
# 5882   Statistical projections, models and ownership ...
# 5891   PIT players' reaction to Le'Veon Bell reads li...
# 5926   FWIW, Steelers C Maurkice Pouncey seems very s...
# 5944   PIT getting testy with Le'Veon Bell. https://t...
# 6333   RT @adamlevitan: Statistical projections, mode...
# 7225   RT @ScottBarrettDFB: Le'Veon Bell vs. his back...
# 7267   In Le'Veon Bell's first three games last year,...
# 10549  I've seen a lot of questions on my timeline ab...
# 10771  Le'Veon Bell is going to walk into the #Steele...
# 10831  This week's mailbag episode is live. I talk Le...
# 10898  And given my general approach to fantasy footb...
# 11882  Week 1 #FantasyFootball ranks talk with @allin...
# 11889  Apparently Le'Veon Bell still not in the build...
# 11899  Get @LateRoundQB's STILLERS opinion about Le'V...
#
#                            created_at  \
# 38     Fri Sep 14 17:14:05 +0000 2018
# 166    Wed Sep 12 13:51:36 +0000 2018
# 300    Sat Sep 15 16:08:20 +0000 2018
# 421    Sun Sep 09 14:07:12 +0000 2018
# 435    Sat Sep 08 19:23:24 +0000 2018
# 469    Wed Sep 05 18:18:50 +0000 2018
# 470    Wed Sep 05 16:46:54 +0000 2018
# 476    Wed Sep 05 11:22:04 +0000 2018
# 505    Mon Sep 03 15:24:39 +0000 2018
# 652    Sun Sep 09 06:33:05 +0000 2018
# 658    Fri Sep 07 14:22:05 +0000 2018
# 666    Thu Sep 06 01:00:32 +0000 2018
# 672    Wed Sep 05 19:32:31 +0000 2018
# 698    Tue Sep 04 00:11:34 +0000 2018
# 719    Mon Sep 03 18:58:04 +0000 2018
# 808    Fri Aug 31 19:59:03 +0000 2018
# 853    Wed Aug 29 16:08:03 +0000 2018
# 863    Tue Aug 28 21:53:02 +0000 2018
# 1121   Thu Sep 13 13:26:08 +0000 2018
# 1168   Thu Sep 13 01:37:01 +0000 2018
# 1303   Thu Sep 13 17:01:08 +0000 2018
# 1571   Wed Sep 12 14:43:22 +0000 2018
# 1671   Sun Sep 09 19:09:53 +0000 2018
# 1759   Thu Sep 06 21:45:36 +0000 2018
# 1784   Wed Sep 05 18:04:20 +0000 2018
# 1790   Wed Sep 05 14:07:00 +0000 2018
# 1988   Sat Sep 08 21:27:24 +0000 2018
# 2454   Wed Sep 12 19:42:19 +0000 2018
# 2501   Mon Sep 10 22:46:37 +0000 2018
# 2535   Sun Sep 09 17:52:37 +0000 2018
# 2598   Thu Sep 06 15:10:00 +0000 2018
# 2616   Wed Sep 05 17:47:10 +0000 2018
# 2632   Tue Sep 04 23:03:11 +0000 2018
# 2657   Mon Sep 03 20:40:52 +0000 2018
# 2746   Thu Sep 06 10:45:37 +0000 2018
# 3212   Thu Aug 16 19:18:11 +0000 2018
# 4063   Wed Sep 05 22:57:58 +0000 2018
# 4932   Wed Sep 05 22:14:47 +0000 2018
# 5400   Sat Sep 15 16:10:41 +0000 2018
# 5616   Wed Sep 12 12:39:45 +0000 2018
# 5633   Tue Sep 11 17:18:16 +0000 2018
# 5801   Sun Sep 09 23:12:04 +0000 2018
# 5882   Thu Sep 06 15:22:38 +0000 2018
# 5891   Thu Sep 06 13:27:40 +0000 2018
# 5926   Tue Sep 04 12:57:10 +0000 2018
# 5944   Mon Sep 03 15:27:08 +0000 2018
# 6333   Thu Sep 06 15:29:35 +0000 2018
# 7225   Mon Sep 10 14:32:03 +0000 2018
# 7267   Mon Sep 03 16:01:36 +0000 2018
# 10549  Thu Sep 13 19:06:01 +0000 2018
# 10771  Wed Sep 05 20:20:19 +0000 2018
# 10831  Fri Sep 14 13:07:21 +0000 2018
# 10898  Thu Sep 13 14:43:38 +0000 2018
# 11882  Wed Sep 05 17:40:18 +0000 2018
# 11889  Wed Sep 05 13:02:53 +0000 2018
# 11899  Tue Sep 04 21:14:51 +0000 2018
#
#                                                     user  \
# 38     {'id': 20950232, 'id_str': '20950232', 'name':...
# 166    {'id': 20950232, 'id_str': '20950232', 'name':...
# 300    {'id': 51263592, 'id_str': '51263592', 'name':...
# 421    {'id': 51263592, 'id_str': '51263592', 'name':...
# 435    {'id': 51263592, 'id_str': '51263592', 'name':...
# 469    {'id': 51263592, 'id_str': '51263592', 'name':...
# 470    {'id': 51263592, 'id_str': '51263592', 'name':...
# 476    {'id': 51263592, 'id_str': '51263592', 'name':...
# 505    {'id': 51263592, 'id_str': '51263592', 'name':...
# 652    {'id': 30687192, 'id_str': '30687192', 'name':...
# 658    {'id': 30687192, 'id_str': '30687192', 'name':...
# 666    {'id': 30687192, 'id_str': '30687192', 'name':...
# 672    {'id': 30687192, 'id_str': '30687192', 'name':...
# 698    {'id': 30687192, 'id_str': '30687192', 'name':...
# 719    {'id': 30687192, 'id_str': '30687192', 'name':...
# 808    {'id': 30687192, 'id_str': '30687192', 'name':...
# 853    {'id': 30687192, 'id_str': '30687192', 'name':...
# 863    {'id': 30687192, 'id_str': '30687192', 'name':...
# 1121   {'id': 33774346, 'id_str': '33774346', 'name':...
# 1168   {'id': 33774346, 'id_str': '33774346', 'name':...
# 1303   {'id': 174035054, 'id_str': '174035054', 'name...
# 1571   {'id': 185125451, 'id_str': '185125451', 'name...
# 1671   {'id': 185125451, 'id_str': '185125451', 'name...
# 1759   {'id': 185125451, 'id_str': '185125451', 'name...
# 1784   {'id': 185125451, 'id_str': '185125451', 'name...
# 1790   {'id': 185125451, 'id_str': '185125451', 'name...
# 1988   {'id': 20899023, 'id_str': '20899023', 'name':...
# 2454   {'id': 58919137, 'id_str': '58919137', 'name':...
# 2501   {'id': 58919137, 'id_str': '58919137', 'name':...
# 2535   {'id': 58919137, 'id_str': '58919137', 'name':...
# 2598   {'id': 58919137, 'id_str': '58919137', 'name':...
# 2616   {'id': 58919137, 'id_str': '58919137', 'name':...
# 2632   {'id': 58919137, 'id_str': '58919137', 'name':...
# 2657   {'id': 58919137, 'id_str': '58919137', 'name':...
# 2746   {'id': 108318595, 'id_str': '108318595', 'name...
# 3212   {'id': 35385104, 'id_str': '35385104', 'name':...
# 4063   {'id': 2557521, 'id_str': '2557521', 'name': '...
# 4932   {'id': 1265004110, 'id_str': '1265004110', 'na...
# 5400   {'id': 3443902392, 'id_str': '3443902392', 'na...
# 5616   {'id': 3443902392, 'id_str': '3443902392', 'na...
# 5633   {'id': 3443902392, 'id_str': '3443902392', 'na...
# 5801   {'id': 42987732, 'id_str': '42987732', 'name':...
# 5882   {'id': 42987732, 'id_str': '42987732', 'name':...
# 5891   {'id': 42987732, 'id_str': '42987732', 'name':...
# 5926   {'id': 42987732, 'id_str': '42987732', 'name':...
# 5944   {'id': 42987732, 'id_str': '42987732', 'name':...
# 6333   {'id': 24108943, 'id_str': '24108943', 'name':...
# 7225   {'id': 1852555963, 'id_str': '1852555963', 'na...
# 7267   {'id': 1852555963, 'id_str': '1852555963', 'na...
# 10549  {'id': 368434779, 'id_str': '368434779', 'name...
# 10771  {'id': 368434779, 'id_str': '368434779', 'name...
# 10831  {'id': 596744235, 'id_str': '596744235', 'name...
# 10898  {'id': 596744235, 'id_str': '596744235', 'name...
# 11882  {'id': 168570138, 'id_str': '168570138', 'name...
# 11889  {'id': 168570138, 'id_str': '168570138', 'name...
# 11899  {'id': 168570138, 'id_str': '168570138', 'name...
#
#                        label  tweet_count  compound_score  positive_score  \
# 38        Rotoworld Football           39          0.5106           0.148
# 166       Rotoworld Football          167          0.0000           0.000
# 300            Adam Schefter            1         -0.2960           0.000
# 421            Adam Schefter          122          0.0000           0.000
# 435            Adam Schefter          136          0.0000           0.000
# 469            Adam Schefter          170          0.6124           0.185
# 470            Adam Schefter          171          0.0000           0.000
# 476            Adam Schefter          177          0.2144           0.078
# 505            Adam Schefter          206         -0.6486           0.000
# 652    Sporting News Fantasy           53          0.0000           0.000
# 658    Sporting News Fantasy           59          0.4019           0.197
# 666    Sporting News Fantasy           67          0.0000           0.000
# 672    Sporting News Fantasy           73          0.0000           0.000
# 698    Sporting News Fantasy           99          0.0000           0.000
# 719    Sporting News Fantasy          120          0.0000           0.000
# 808    Sporting News Fantasy          209         -0.6486           0.000
# 853    Sporting News Fantasy          254          0.4588           0.167
# 863    Sporting News Fantasy          264         -0.2960           0.000
# 1121               Josh ADHD          222         -0.3400           0.000
# 1168               Josh ADHD          269          0.5719           0.167
# 1303    PFF Fantasy Football          104          0.2023           0.083
# 1571             FantasyPros           72          0.0000           0.000
# 1671             FantasyPros          172          0.0516           0.230
# 1759             FantasyPros          260          0.0000           0.000
# 1784             FantasyPros          285         -0.1531           0.000
# 1790             FantasyPros          291          0.0000           0.000
# 1988           Matthew Berry          189         -0.4215           0.000
# 2454             Field Yates           55          0.0000           0.000
# 2501             Field Yates          102          0.0000           0.000
# 2535             Field Yates          136          0.4215           0.109
# 2598             Field Yates          199          0.0000           0.000
# 2616             Field Yates          217          0.3818           0.110
# 2632             Field Yates          233          0.3400           0.124
# 2657             Field Yates          258          0.0000           0.000
# 2746           Eric Karabell           47          0.3612           0.094
# 3212    Tristan H. Cockcroft          213          0.3612           0.111
# 4063                    ESPN          164          0.0000           0.000
# 4932            Sean Koerner          133          0.0000           0.000
# 5400         FantasyLabs NFL            1         -0.2584           0.000
# 5616         FantasyLabs NFL          217          0.0000           0.000
# 5633         FantasyLabs NFL          234          0.0000           0.000
# 5801            Adam Levitan          102          0.0000           0.000
# 5882            Adam Levitan          183          0.0000           0.000
# 5891            Adam Levitan          192          0.3612           0.143
# 5926            Adam Levitan          227          0.3804           0.166
# 5944            Adam Levitan          245          0.0000           0.000
# 6333          Jonathan Bales           34          0.0000           0.000
# 7225         Graham Barfield           26          0.0000           0.000
# 7267         Graham Barfield           68          0.0000           0.000
# 10549          Mike Tagliere           50          0.0000           0.000
# 10771          Mike Tagliere          272          0.0000           0.000
# 10831         JJ Zachariason           32          0.0000           0.000
# 10898         JJ Zachariason           99          0.0000           0.000
# 11882     Christopher Harris          183          0.0000           0.000
# 11889     Christopher Harris          190          0.0000           0.000
# 11899     Christopher Harris          200          0.0000           0.000
#
#        negative_score  neutral_score
# 38              0.000          0.852
# 166             0.000          1.000
# 300             0.095          0.905
# 421             0.000          1.000
# 435             0.000          1.000
# 469             0.000          0.815
# 470             0.000          1.000
# 476             0.000          0.922
# 505             0.227          0.773
# 652             0.000          1.000
# 658             0.000          0.803
# 666             0.000          1.000
# 672             0.000          1.000
# 698             0.000          1.000
# 719             0.000          1.000
# 808             0.275          0.725
# 853             0.000          0.833
# 863             0.095          0.905
# 1121            0.091          0.909
# 1168            0.057          0.776
# 1303            0.000          0.917
# 1571            0.000          1.000
# 1671            0.214          0.556
# 1759            0.000          1.000
# 1784            0.127          0.873
# 1790            0.000          1.000
# 1988            0.113          0.887
# 2454            0.000          1.000
# 2501            0.000          1.000
# 2535            0.000          0.891
# 2598            0.000          1.000
# 2616            0.000          0.890
# 2632            0.000          0.876
# 2657            0.000          1.000
# 2746            0.000          0.906
# 3212            0.000          0.889
# 4063            0.000          1.000
# 4932            0.000          1.000
# 5400            0.145          0.855
# 5616            0.000          1.000
# 5633            0.000          1.000
# 5801            0.000          1.000
# 5882            0.000          1.000
# 5891            0.000          0.857
# 5926            0.000          0.834
# 5944            0.000          1.000
# 6333            0.000          1.000
# 7225            0.000          1.000
# 7267            0.000          1.000
# 10549           0.000          1.000
# 10771           0.000          1.000
# 10831           0.000          1.000
# 10898           0.000          1.000
# 11882           0.000          1.000
# 11889           0.000          1.000
# 11899           0.000          1.000

# %%
bell_df.get('compound_score').mean()
# Out:
# 0.045875000000000006

# %%
#creating a string of just the created_at info I want
str(df['created_at'].iloc[0][4:10]+' '+df['created_at'].iloc[0][26:30])
# Out:
# 'Sep 15 2018'

# %%
#convert to datetime
datetime.strptime('Sep 12 2018', '%b %d %Y')
# Out:
# datetime.datetime(2018, 9, 12, 0, 0)

# %%
#creating new column of just date information
df['date'] = df['created_at'].map(lambda x: str(x[4:10]+' '+x[26:30]))

# %%
#creating date column to datetime in new column
df['datetime'] = df['date'].map(lambda x: datetime.strptime(x, '%b %d %Y'))

# %%
df['datetime'].iloc[0]
# Out:
# Timestamp('2018-09-15 00:00:00')

# %%
#can I do this dynamically?????????????????????????????????????
one_week_ago = datetime.strptime('Sep 8 2018', '%b %d %Y')

# %%
#creating df of only tweets within one week
recent_tweets = df[df['datetime']>one_week_ago]

# %%
#checking total number of tweets
recent_tweets.describe()
# Out:
#        tweet_count  compound_score  positive_score  negative_score  \
# count  7847.000000     7847.000000     7847.000000     7847.000000
# mean    123.374920        0.099743        0.101031        0.048228
# std      83.528796        0.339200        0.156255        0.102322
# min       1.000000       -0.946300        0.000000        0.000000
# 25%      51.000000        0.000000        0.000000        0.000000
# 50%     111.000000        0.000000        0.000000        0.000000
# 75%     188.000000        0.361200        0.170000        0.000000
# max     300.000000        0.953800        1.000000        0.812000
#
#        neutral_score
# count    7847.000000
# mean        0.850486
# std         0.175701
# min         0.000000
# 25%         0.748000
# 50%         0.888000
# 75%         1.000000
# max         1.000000

# %%
recent_tweets.head()
# Out:
#                                                 text  \
# 0  Bills surprisingly part ways with WR Kerley ht...
# 1  #NFL Week 2 Injury Report: Checking in on Leon...
# 2  #NFL Narratives: @JessePantuosco highlights Ma...
# 3  Despite his lack of production in Week 1, Trav...
# 4  RT @RotoPat: Lots of injury updates to the ran...
#
#                        created_at  \
# 0  Sat Sep 15 16:09:45 +0000 2018
# 1  Sat Sep 15 15:22:05 +0000 2018
# 2  Sat Sep 15 14:19:05 +0000 2018
# 3  Sat Sep 15 12:00:24 +0000 2018
# 4  Fri Sep 14 22:06:40 +0000 2018
#
#                                                 user               label  \
# 0  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
# 1  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
# 2  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
# 3  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
# 4  {'id': 20950232, 'id_str': '20950232', 'name':...  Rotoworld Football
#
#    tweet_count  compound_score  positive_score  negative_score  neutral_score  \
# 0            1          0.2960           0.239           0.000          0.761
# 1            2         -0.4215           0.000           0.157          0.843
# 2            3         -0.7506           0.000           0.348          0.652
# 3            4         -0.0258           0.086           0.090          0.824
# 4            5         -0.0258           0.110           0.114          0.776
#
#           date   datetime
# 0  Sep 15 2018 2018-09-15
# 1  Sep 15 2018 2018-09-15
# 2  Sep 15 2018 2018-09-15
# 3  Sep 15 2018 2018-09-15
# 4  Sep 14 2018 2018-09-14

# %%
#checking to make sure that the date filter worked
recent_tweets['datetime'].value_counts()
# Out:
# 2018-09-14    1298
# 2018-09-13    1155
# 2018-09-10    1090
# 2018-09-11    1060
# 2018-09-12    1019
# 2018-09-09    1007
# 2018-09-07     516
# 2018-09-15     356
# 2018-09-08     346
# Name: datetime, dtype: int64

# %%
recent_tweets = recent_tweets.reset_index()

# %%
recent_tweets['text'].iloc[0]
# Out:
# 'Bills surprisingly part ways with WR Kerley https://t.co/wTlWFqNNAq'

# %%
bell_df = [recent_tweets['text'].str.contains("Le'Veon Bell")]

# %%
bell_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-9d2527827b07> in <module>()
# ----> 1 bell_df.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
player_df = pd.read_csv('player_list.csv', encoding ='latin1')

# %%
player_df.head()
# Out:
#    number               player
# 0       1           Cam Newton
# 1       2           Drew Brees
# 2       3        Aaron Rodgers
# 3       4           Alex Smith
# 4       5   Ben Roethlisberger

# %%
player_df['player'][0][1:]
# Out:
# 'Cam Newton'

# %%
player_df['player'] = player_df['player'].map(lambda x: x[1:])

# %%
player_df['player'].iloc[0]
# Out:
# 'Cam Newton'

# %%
#for each player in the league, need to create a mask for each to get compound score, get mean compound score and append to list
compound_scores = []
for player in player_df['player']:
    temp_df = recent_tweets[recent_tweets['text'].str.contains(player)]
    score_mean = temp_df.get('compound_score').mean()
    compound_scores.append(score_mean)

# %%
#input mean compound score into player table
player_df['compound_score'] = compound_scores
player_df.head()
# Out:
#    number              player  compound_score
# 0       1          Cam Newton       -0.109200
# 1       2          Drew Brees        0.296667
# 2       3       Aaron Rodgers       -0.095170
# 3       4          Alex Smith        0.154164
# 4       5  Ben Roethlisberger       -0.018416

# %%
player_df['compound_score'].mean()
# Out:
# 0.06883564229574976

# %%
#creat bins for positive, neutral, and negative (awesome, good, neutral, concerned, terrible)
bins = [-1, -.5, -.02, .02, .5,  1]
player_df['binned'] = pd.cut(player_df['compound_score'], bins)
player_df.head()
# Out:
#    number              player  compound_score         binned
# 0       1          Cam Newton       -0.109200  (-0.5, -0.02]
# 1       2          Drew Brees        0.296667    (0.02, 0.5]
# 2       3       Aaron Rodgers       -0.095170  (-0.5, -0.02]
# 3       4          Alex Smith        0.154164    (0.02, 0.5]
# 4       5  Ben Roethlisberger       -0.018416  (-0.02, 0.02]

# %%
player_df['binned'] = player_df['binned'].map(lambda x: str(x))

# %%
player_df['binned'].iloc[0]
# Out:
# '(-0.5, -0.02]'

# %%
player_df['binned'].value_counts()
# Out:
# (0.02, 0.5]      85
# (-0.5, -0.02]    41
# (-0.02, 0.02]    21
# (0.5, 1.0]        4
# (-1.0, -0.5]      2
# Name: binned, dtype: int64

# %%
sent_bins = {
    '(-1.0, -0.5]': 'Terrrible',
    '(-0.5, -0.02]': 'Concerned',
    '(-0.02, 0.02]': 'Neutral',
    '(0.02, 0.5]': 'Good',
    '(0.5, 1.0]': 'Awesome'
}

# %%
player_df['expert_sentiment'] = player_df['binned'].map(sent_bins)
player_df.head()
# Out:
#    number              player  compound_score         binned expert_sentiment
# 0       1          Cam Newton       -0.109200  (-0.5, -0.02]        Concerned
# 1       2          Drew Brees        0.296667    (0.02, 0.5]             Good
# 2       3       Aaron Rodgers       -0.095170  (-0.5, -0.02]        Concerned
# 3       4          Alex Smith        0.154164    (0.02, 0.5]             Good
# 4       5  Ben Roethlisberger       -0.018416  (-0.02, 0.02]          Neutral

# %%
player_df['expert_sentiment'].value_counts()
# Out:
# Good         85
# Concerned    41
# Neutral      21
# Awesome       4
# Terrrible     2
# Name: expert_sentiment, dtype: int64

# %%
player_df.to_csv('expert_tweets.csv')

# %%
#end goal = create csv with each player and their compound score. user can query for a player and get a result which shows how
# the fantasy experts feel about that player (positive, negative, or neutral)

# %%
#want to sort by just the last week's data to get current tweets
# one_week_ago = datetime.today() - timedelta(days=7)
# one_week_ago
